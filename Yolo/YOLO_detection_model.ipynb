# %% [markdown]
# #LAB 2: YOLO detection model

# %% [markdown]
# <h4><div style="text-align: right"> Due date: 15:00 Oct 28, 2024.  </div> <br>
# <div style="text-align: right"> Please upload your file and final-report at PLATO before the class in the form of [ID_Name_Lab1.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - You must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# [link text](https://)<h2><span style="color:blue">[201924624] [Nemekhbayar Nomin]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2024-10-28 13:30:56.114039

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])

        with open(list_file) as f:
            lines = f.readlines()

        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)

    def img_pre_process(self, img, boxes, labels):

        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr

        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)

        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)

            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))

            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]

            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]

            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]

            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]

            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range

            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift

                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in

        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))

            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped

        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30))
        cell_size = 1./grid_size

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2

        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel
            ij = (cxcy_sample/cell_size).ceil()-1
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1

            xy = ij*cell_size
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy

        return target

    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)

        target = self.generate_target(img, boxes, labels) # 7x7x30

        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1

        return img, target

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()

        self.pre_train_net = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 192, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(192, 128, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 256, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 256, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 256, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 256, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 256, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 512, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(1024, 512, kernel_size=1, padding=0),
            nn.LeakyReLU(0.1),

            nn.Conv2d(512, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1)
        )

        # Define post_net according to the specified architecture
        self.post_net = nn.Sequential(
            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(1024, 1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),

            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1)
        )

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()

        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %%
y = YOLO()
print(y)
# Out:
# YOLO(
#   (pre_train_net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.1)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.1)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.1)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.1)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.1)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (16): LeakyReLU(negative_slope=0.1)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): LeakyReLU(negative_slope=0.1)
#     (19): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (20): LeakyReLU(negative_slope=0.1)
#     (21): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): LeakyReLU(negative_slope=0.1)
#     (23): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (24): LeakyReLU(negative_slope=0.1)
#     (25): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): LeakyReLU(negative_slope=0.1)
#     (27): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (28): LeakyReLU(negative_slope=0.1)
#     (29): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): LeakyReLU(negative_slope=0.1)
#     (31): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (32): LeakyReLU(negative_slope=0.1)
#     (33): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): LeakyReLU(negative_slope=0.1)
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (36): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (37): LeakyReLU(negative_slope=0.1)
#     (38): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): LeakyReLU(negative_slope=0.1)
#   )
#   (post_net): Sequential(
#     (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.1)
#     (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.1)
#     (6): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.1)
#   )
#   (FC1): Sequential(
#     (0): Linear(in_features=50176, out_features=4096, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (FC2): Sequential(
#     (0): Linear(in_features=4096, out_features=1470, bias=True)
#   )
# )

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from torchinfo import summary
summary(y)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# YOLO                                     --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       9,472
# │    └─LeakyReLU: 2-2                    --
# │    └─MaxPool2d: 2-3                    --
# │    └─Conv2d: 2-4                       110,784
# │    └─LeakyReLU: 2-5                    --
# │    └─MaxPool2d: 2-6                    --
# │    └─Conv2d: 2-7                       24,704
# │    └─LeakyReLU: 2-8                    --
# │    └─Conv2d: 2-9                       295,168
# │    └─LeakyReLU: 2-10                   --
# │    └─Conv2d: 2-11                      65,792
# │    └─LeakyReLU: 2-12                   --
# │    └─Conv2d: 2-13                      1,180,160
# │    └─LeakyReLU: 2-14                   --
# │    └─MaxPool2d: 2-15                   --
# │    └─Conv2d: 2-16                      131,328
# │    └─LeakyReLU: 2-17                   --
# │    └─Conv2d: 2-18                      1,180,160
# │    └─LeakyReLU: 2-19                   --
# │    └─Conv2d: 2-20                      131,328
# │    └─LeakyReLU: 2-21                   --
# │    └─Conv2d: 2-22                      1,180,160
# │    └─LeakyReLU: 2-23                   --
# │    └─Conv2d: 2-24                      131,328
# │    └─LeakyReLU: 2-25                   --
# │    └─Conv2d: 2-26                      1,180,160
# │    └─LeakyReLU: 2-27                   --
# │    └─Conv2d: 2-28                      131,328
# │    └─LeakyReLU: 2-29                   --
# │    └─Conv2d: 2-30                      1,180,160
# │    └─LeakyReLU: 2-31                   --
# │    └─Conv2d: 2-32                      262,656
# │    └─LeakyReLU: 2-33                   --
# │    └─Conv2d: 2-34                      4,719,616
# │    └─LeakyReLU: 2-35                   --
# │    └─MaxPool2d: 2-36                   --
# │    └─Conv2d: 2-37                      524,800
# │    └─LeakyReLU: 2-38                   --
# │    └─Conv2d: 2-39                      4,719,616
# │    └─LeakyReLU: 2-40                   --
# ├─Sequential: 1-2                        --
# │    └─Conv2d: 2-41                      9,438,208
# │    └─LeakyReLU: 2-42                   --
# │    └─Conv2d: 2-43                      9,438,208
# │    └─LeakyReLU: 2-44                   --
# │    └─Conv2d: 2-45                      9,438,208
# │    └─LeakyReLU: 2-46                   --
# │    └─Conv2d: 2-47                      9,438,208
# │    └─LeakyReLU: 2-48                   --
# ├─Sequential: 1-3                        --
# │    └─Linear: 2-49                      205,524,992
# │    └─LeakyReLU: 2-50                   --
# │    └─Dropout: 2-51                     --
# ├─Sequential: 1-4                        --
# │    └─Linear: 2-52                      6,022,590
# =================================================================
# Total params: 266,459,134
# Trainable params: 266,459,134
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

class yoloLoss(nn.Module):
    def __init__(self, l_coord, l_noobj):
        super(yoloLoss, self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj

    def compute_prob_error(self, pred, target):
        contain = target[:, :, :, 4] > 0
        contain = contain.unsqueeze(-1).expand_as(target)

        prob_loss = F.mse_loss(pred[contain].view(-1, 30)[:, 10:], target[contain].view(-1, 30)[:, 10:], reduction='sum')
        return prob_loss

    def not_contain_obj_error(self, pred, target):
        not_contain = target[:, :, :, 4] == 0
        not_contain = not_contain.unsqueeze(-1).expand_as(target)

        noobj_loss1 = F.mse_loss(pred[not_contain].view(-1, 30)[:, 4], target[not_contain].view(-1, 30)[:, 4], reduction='sum')
        return noobj_loss1

    def contain_obj_error(self, pred, target):
        contain = target[:, :, :, 4] > 0
        contain = contain.unsqueeze(3).expand_as(target)

        contain_pred = pred[contain].contiguous().view(-1, 30)
        box_pred = contain_pred[:, :10].contiguous().view(-1, 5)

        contain_target = target[contain].contiguous().view(-1, 30)
        box_target = contain_target[:, :10].contiguous().view(-1, 5)

        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_()
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_()

        target_iou_gt = torch.zeros(box_target[:, 0].size()).cuda()

        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2]
            box_p_coord = Variable(torch.FloatTensor(box_p.size()))
            box_p_coord[:, :2] = box_p[:, :2] - 0.5 * box_p[:, 2:4]
            box_p_coord[:, 2:4] = box_p[:, :2] + 0.5 * box_p[:, 2:4]

            box_t = box_target[i].contiguous().view(-1, 5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:, :2] = box_t[:, :2] - 0.5 * box_t[:, 2:4]
            box_t_coord[:, 2:4] = box_t[:, :2] + 0.5 * box_t[:, 2:4]

            iou = self.compute_iou(box_p_coord[:, :4], box_t_coord[:, :4])
            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i + max_idx] = 1
            contain_noobj_mask[i + 1 - max_idx] = 1
            target_iou_gt[i + max_idx] = gt_iou.data.cuda()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)

        contain_box_pred = box_pred[contain_obj_mask].view(-1, 5)
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1, 5)

        contain_box_target = box_target[contain_obj_mask].view(-1, 5)
        not_contain_box_target = box_target[contain_noobj_mask].view(-1, 5)
        not_contain_box_target[:, 4] = 0

        contain_iou_target = target_iou_gt.view(-1, 1)

        obj_loss = F.mse_loss(contain_box_pred[:, 4], contain_iou_target, reduction='sum')
        xy_loss = F.mse_loss(contain_box_pred[:, :2], contain_box_target[:, :2], reduction='sum')
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:, 2:4] + 1e-6), torch.sqrt(contain_box_target[:, 2:4] + 1e-6), reduction='sum')
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:, 4], not_contain_box_target[:, 4], reduction='sum')

        return obj_loss, xy_loss, wh_loss, noobj_loss2

    def compute_iou(self, box_p, box_t):
        pred_area = (box_p[:, 2] - box_p[:, 0]) * (box_p[:, 3] - box_p[:, 1])
        target_area = (box_t[:, 2] - box_t[:, 0]) * (box_t[:, 3] - box_t[:, 1])

        box_p = box_p.unsqueeze(1).expand(2, 1, 4)
        box_t = box_t.unsqueeze(0).expand(2, 1, 4)

        inter_lt = torch.max(box_p[:, :, :2], box_t[:, :, :2])
        inter_rb = torch.min(box_p[:, :, 2:], box_t[:, :, 2:])

        wh = inter_rb - inter_lt
        wh[wh < 0] = 0

        inter_area = wh[:, :, 0] * wh[:, :, 1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)

        iou = inter_area / (pred_area + target_area - inter_area)

        return iou

    def forward(self, pred, target):
        batch_size = pred.size()[0]

        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)

        total_loss = (self.l_coord * (xy_loss + wh_loss) + obj_loss + self.l_noobj * (noobj_loss1 + noobj_loss2) + prob_loss)

        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/lab2.zip -d ./
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./lab2/utils/Generate_dataset/images/000114.jpg
#    creating: ./lab2/utils/Generate_dataset/images/.ipynb_checkpoints/
#   inflating: ./lab2/utils/Generate_dataset/images/.ipynb_checkpoints/000011-checkpoint.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002057.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000422.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004504.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004217.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001193.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002843.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007960.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000136.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005503.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000757.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005562.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004453.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000924.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003917.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007560.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002597.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005155.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006571.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007734.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004216.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000442.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004314.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008007.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001616.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003055.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002349.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000668.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005927.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002973.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005241.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000300.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007825.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005642.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006211.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004724.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004802.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000135.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002619.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001601.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003381.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007674.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000669.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005091.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004615.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005598.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006467.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005394.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007733.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003693.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002467.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002177.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005962.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001305.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003964.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007131.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007818.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004172.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001694.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002217.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004044.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007014.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007930.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004226.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004467.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007948.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002607.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006979.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003878.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007160.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000086.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004147.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007286.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002160.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005089.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000593.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006415.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003476.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006907.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004377.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005099.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007659.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003615.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001098.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006974.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004115.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004940.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007257.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004758.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001306.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001019.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004401.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007802.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007312.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006326.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000618.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004847.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004097.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000037.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007698.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007041.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000721.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004883.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003332.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003168.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004431.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006701.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000254.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002447.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002210.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005201.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000833.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002920.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003478.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005402.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002522.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003683.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003283.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003718.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000465.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001874.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007169.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006051.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000747.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007291.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000137.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007918.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000718.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006502.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000572.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004202.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007441.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007829.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006394.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000801.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006494.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007617.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003480.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006996.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000803.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006232.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002822.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006961.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007787.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005540.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005317.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001032.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004472.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002232.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000074.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005043.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001208.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007529.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000945.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001331.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006741.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003733.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003726.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005957.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003630.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007096.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004851.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004945.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007710.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001924.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003999.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003456.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003570.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007515.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004343.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007304.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000128.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001216.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005432.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007638.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004993.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002740.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005446.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002358.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000741.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007938.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006454.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007880.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005300.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006752.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007711.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005785.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003347.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001128.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004697.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007405.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000098.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006007.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001328.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004254.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003904.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002149.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007973.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004114.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002292.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004419.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007290.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003080.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007309.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003319.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003268.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005493.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001817.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001422.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007556.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004080.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006717.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001736.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001573.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002517.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005528.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004645.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004658.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006581.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007135.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003287.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006913.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000119.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000049.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004086.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002304.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002707.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004153.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005694.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005810.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002076.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002577.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003920.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001202.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006870.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003095.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006946.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001623.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001873.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001153.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002198.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004079.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003666.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002681.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006641.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001075.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000284.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003257.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000103.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003440.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003559.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002038.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007027.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002200.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006749.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003348.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000015.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003504.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006928.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006733.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006758.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005651.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001135.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003266.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005460.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004199.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004021.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007145.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003901.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004002.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005076.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005924.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002275.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001835.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006063.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007026.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005109.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004752.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002473.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008135.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002831.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000255.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005537.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002610.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001034.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004787.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005949.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002961.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002271.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006853.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006044.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004442.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000425.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000877.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002814.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005238.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007367.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006498.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002852.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002453.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006510.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000324.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006525.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003472.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000316.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006263.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007254.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003364.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005372.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001851.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002716.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001213.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000401.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005194.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003125.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001123.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007693.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000018.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004602.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001774.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005106.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000853.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007807.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007574.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006324.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003447.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006831.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003661.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005038.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004078.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005501.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005157.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008025.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004521.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001663.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000261.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007386.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000362.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002871.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000785.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003371.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005607.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008129.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000067.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008020.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006596.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003445.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004533.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003785.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007409.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007507.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002118.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000724.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001507.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001965.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006518.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001003.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002205.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007867.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005706.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002694.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002084.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004050.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001379.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004306.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001249.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004458.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002552.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001111.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007907.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006998.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003715.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003109.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001280.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003481.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003962.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006790.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002574.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001401.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004313.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001377.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002769.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007156.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001863.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005426.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007937.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007995.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004577.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002162.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001996.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003870.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006315.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000418.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002955.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003490.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007115.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003171.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002138.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005621.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005892.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004477.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003980.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003119.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006785.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007588.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004402.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000351.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000759.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002959.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003046.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007399.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004543.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004670.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001322.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005683.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004975.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005793.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002720.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006871.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002629.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001552.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006333.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006006.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002485.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004427.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005484.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006228.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007794.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006890.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007993.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006121.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005538.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000844.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005437.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007155.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002876.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005904.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007288.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001022.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004541.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005142.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004337.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005046.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000082.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008030.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005632.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005580.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003479.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005516.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002661.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005381.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005452.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002839.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000976.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007806.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000548.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006655.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001058.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006754.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001291.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001626.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004335.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000640.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005776.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002923.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001984.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002396.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003143.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007459.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003174.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002541.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000600.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004302.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002746.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007024.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003101.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005192.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001897.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006090.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004845.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006888.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007242.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006405.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001283.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003523.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002440.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001535.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001592.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004290.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006245.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003460.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006336.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007082.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003114.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005688.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002733.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002346.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003823.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000079.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002908.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001820.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000778.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002754.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006024.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003375.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007331.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006651.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005458.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003326.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002535.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001991.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000957.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005891.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002679.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001844.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004988.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001587.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003782.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005474.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006675.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003812.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001983.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005974.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004906.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007001.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005744.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006265.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007171.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004755.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007478.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007866.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006099.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006724.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001767.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006590.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004278.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002851.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001080.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006037.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001369.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005770.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007613.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003719.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005987.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001223.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003805.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003794.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003405.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002805.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003925.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006992.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005737.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000722.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000054.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003238.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006039.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005277.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006685.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002865.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006294.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005955.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006149.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001804.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002840.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001048.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008054.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006017.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001044.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000968.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000471.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003302.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004734.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003334.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007665.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007944.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007360.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000301.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000897.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004593.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004680.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007063.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004979.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004860.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001433.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000488.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004316.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001252.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001908.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007701.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007143.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001132.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006818.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000505.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004107.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002408.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004130.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003574.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006993.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003033.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000975.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003227.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006991.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001339.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005228.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000011.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005126.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001462.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007562.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001913.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003533.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002370.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005275.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001929.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007502.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006420.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005557.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003931.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001190.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005211.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001542.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001568.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003312.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007844.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004572.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006182.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001217.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005820.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001994.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001089.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002052.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004700.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005051.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005127.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000402.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003040.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004888.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004981.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005913.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005476.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001912.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006877.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005646.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004891.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000195.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005649.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005249.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001966.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007757.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005932.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002222.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006383.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006328.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001702.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008006.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006114.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001505.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006423.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001308.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001195.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007823.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002243.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004188.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004071.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004736.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007013.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000183.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004444.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/006283.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003672.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/003552.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004688.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004187.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/000864.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/002143.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007827.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/008011.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/005512.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004933.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007541.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/004586.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001562.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001560.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001783.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/007282.jpg
#   inflating: ./lab2/utils/Generate_dataset/images/001956.jpg
#   inflating: ./lab2/utils/Generate_dataset/voc2012.txt
#   inflating: ./lab2/utils/Generate_dataset/voc2007+2012.txt
#   inflating: ./lab2/utils/Generate_dataset/voc2007test.txt
#   inflating: ./lab2/utils/Generate_dataset/voc2007.txt
#    creating: ./lab2/__pycache__/
#   inflating: ./lab2/__pycache__/util.cpython-38.pyc
#    creating: ./lab2/all_img/
#   inflating: ./lab2/all_img/2010_000948.jpg
#   inflating: ./lab2/all_img/006495.jpg
#   inflating: ./lab2/all_img/2009_001589.jpg
#   inflating: ./lab2/all_img/2010_002204.jpg
#   inflating: ./lab2/all_img/2010_001590.jpg
#   inflating: ./lab2/all_img/2010_002713.jpg
#   inflating: ./lab2/all_img/007838.jpg
#   inflating: ./lab2/all_img/003154.jpg
#   inflating: ./lab2/all_img/000091.jpg
#   inflating: ./lab2/all_img/2010_005592.jpg
#   inflating: ./lab2/all_img/2007_004841.jpg
#   inflating: ./lab2/all_img/006884.jpg
#   inflating: ./lab2/all_img/2008_007791.jpg
#   inflating: ./lab2/all_img/2011_002913.jpg
#   inflating: ./lab2/all_img/2008_004284.jpg
#   inflating: ./lab2/all_img/2010_000048.jpg
#   inflating: ./lab2/all_img/009743.jpg
#   inflating: ./lab2/all_img/2009_000591.jpg
#   inflating: ./lab2/all_img/2008_001610.jpg
#   inflating: ./lab2/all_img/2010_000655.jpg
#   inflating: ./lab2/all_img/2008_005878.jpg
#   inflating: ./lab2/all_img/2010_003675.jpg
#   inflating: ./lab2/all_img/2010_005323.jpg
#   inflating: ./lab2/all_img/2010_001124.jpg
#   inflating: ./lab2/all_img/2010_002972.jpg
#   inflating: ./lab2/all_img/2008_000336.jpg
#   inflating: ./lab2/all_img/004643.jpg
#   inflating: ./lab2/all_img/2010_001838.jpg
#   inflating: ./lab2/all_img/001488.jpg
#   inflating: ./lab2/all_img/000263.jpg
#   inflating: ./lab2/all_img/2009_002103.jpg
#   inflating: ./lab2/all_img/2010_002876.jpg
#   inflating: ./lab2/all_img/008859.jpg
#   inflating: ./lab2/all_img/2008_003713.jpg
#   inflating: ./lab2/all_img/2010_001718.jpg
#   inflating: ./lab2/all_img/2008_006564.jpg
#   inflating: ./lab2/all_img/005159.jpg
#   inflating: ./lab2/all_img/2010_004116.jpg
#   inflating: ./lab2/all_img/004430.jpg
#   inflating: ./lab2/all_img/004120.jpg
#   inflating: ./lab2/all_img/2009_004411.jpg
#   inflating: ./lab2/all_img/2008_006980.jpg
#   inflating: ./lab2/all_img/004035.jpg
#   inflating: ./lab2/all_img/004135.jpg
#   inflating: ./lab2/all_img/001194.jpg
#   inflating: ./lab2/all_img/007343.jpg
#   inflating: ./lab2/all_img/2008_003189.jpg
#   inflating: ./lab2/all_img/2010_002868.jpg
#   inflating: ./lab2/all_img/2008_008748.jpg
#   inflating: ./lab2/all_img/2009_001205.jpg
#   inflating: ./lab2/all_img/004429.jpg
#   inflating: ./lab2/all_img/2007_006212.jpg
#   inflating: ./lab2/all_img/002129.jpg
#   inflating: ./lab2/all_img/006183.jpg
#   inflating: ./lab2/all_img/2009_005232.jpg
#   inflating: ./lab2/all_img/2011_001801.jpg
#   inflating: ./lab2/all_img/2008_000999.jpg
#   inflating: ./lab2/all_img/2009_002908.jpg
#   inflating: ./lab2/all_img/008809.jpg
#   inflating: ./lab2/all_img/2009_001916.jpg
#   inflating: ./lab2/all_img/008100.jpg
#   inflating: ./lab2/all_img/2010_000690.jpg
#   inflating: ./lab2/all_img/2010_005914.jpg
#   inflating: ./lab2/all_img/2010_004307.jpg
#   inflating: ./lab2/all_img/2010_000270.jpg
#   inflating: ./lab2/all_img/2008_000761.jpg
#   inflating: ./lab2/all_img/2009_005104.jpg
#   inflating: ./lab2/all_img/008502.jpg
#   inflating: ./lab2/all_img/004034.jpg
#   inflating: ./lab2/all_img/2010_004888.jpg
#   inflating: ./lab2/all_img/001332.jpg
#   inflating: ./lab2/all_img/001582.jpg
#   inflating: ./lab2/all_img/2010_005992.jpg
#   inflating: ./lab2/all_img/005078.jpg
#   inflating: ./lab2/all_img/2010_002105.jpg
#   inflating: ./lab2/all_img/2008_000050.jpg
#   inflating: ./lab2/all_img/003525.jpg
#   inflating: ./lab2/all_img/2010_004457.jpg
#   inflating: ./lab2/all_img/2009_001606.jpg
#   inflating: ./lab2/all_img/2009_000032.jpg
#   inflating: ./lab2/all_img/2008_005362.jpg
#   inflating: ./lab2/all_img/2010_002365.jpg
#   inflating: ./lab2/all_img/2008_006166.jpg
#   inflating: ./lab2/all_img/003885.jpg
#   inflating: ./lab2/all_img/006277.jpg
#   inflating: ./lab2/all_img/2008_007764.jpg
#   inflating: ./lab2/all_img/000077.jpg
#   inflating: ./lab2/all_img/2009_000778.jpg
#   inflating: ./lab2/all_img/2010_004008.jpg
#   inflating: ./lab2/all_img/2008_003374.jpg
#   inflating: ./lab2/all_img/2010_000286.jpg
#   inflating: ./lab2/all_img/002880.jpg
#   inflating: ./lab2/all_img/000161.jpg
#   inflating: ./lab2/all_img/005293.jpg
#   inflating: ./lab2/all_img/002917.jpg
#   inflating: ./lab2/all_img/2008_006249.jpg
# ...
#   inflating: ./lab2/all_img/006325.jpg
#   inflating: ./lab2/all_img/2011_003154.jpg
#   inflating: ./lab2/all_img/2008_002681.jpg
#   inflating: ./lab2/all_img/007011.jpg
#   inflating: ./lab2/all_img/2011_000180.jpg
#   inflating: ./lab2/all_img/2007_001587.jpg
#   inflating: ./lab2/all_img/2010_005640.jpg
#   inflating: ./lab2/all_img/2010_001154.jpg
#   inflating: ./lab2/all_img/006593.jpg
#   inflating: ./lab2/all_img/005970.jpg
#   inflating: ./lab2/all_img/000756.jpg
#   inflating: ./lab2/all_img/2009_003608.jpg
#   inflating: ./lab2/all_img/2010_003582.jpg
#   inflating: ./lab2/all_img/2008_007448.jpg
#   inflating: ./lab2/all_img/004618.jpg
#   inflating: ./lab2/all_img/2010_004957.jpg
#   inflating: ./lab2/all_img/2010_004676.jpg
#   inflating: ./lab2/all_img/2008_003577.jpg
#   inflating: ./lab2/all_img/2010_002947.jpg
#   inflating: ./lab2/all_img/2009_001366.jpg
#   inflating: ./lab2/all_img/007622.jpg
#   inflating: ./lab2/all_img/2011_002742.jpg
#   inflating: ./lab2/all_img/008093.jpg
#   inflating: ./lab2/all_img/000887.jpg
#   inflating: ./lab2/all_img/2008_004802.jpg
#   inflating: ./lab2/all_img/004016.jpg
#   inflating: ./lab2/all_img/2011_001033.jpg
#   inflating: ./lab2/all_img/2008_007836.jpg
#   inflating: ./lab2/all_img/004674.jpg
#   inflating: ./lab2/all_img/009116.jpg
#   inflating: ./lab2/all_img/2010_004756.jpg
#   inflating: ./lab2/all_img/002995.jpg
#   inflating: ./lab2/all_img/2008_002182.jpg
#   inflating: ./lab2/all_img/002315.jpg
#   inflating: ./lab2/all_img/001610.jpg
#   inflating: ./lab2/all_img/007525.jpg
#   inflating: ./lab2/all_img/2008_003303.jpg
#   inflating: ./lab2/all_img/005406.jpg
#   inflating: ./lab2/all_img/2009_004442.jpg
#   inflating: ./lab2/all_img/2008_006361.jpg
#   inflating: ./lab2/all_img/2010_002857.jpg
#   inflating: ./lab2/all_img/2010_000159.jpg
#   inflating: ./lab2/all_img/2008_005805.jpg
#   inflating: ./lab2/all_img/2009_001536.jpg
#   inflating: ./lab2/all_img/2011_001455.jpg
#   inflating: ./lab2/all_img/2009_002400.jpg
#   inflating: ./lab2/all_img/2009_000181.jpg
#   inflating: ./lab2/all_img/2008_004189.jpg
#   inflating: ./lab2/all_img/2008_005451.jpg
#   inflating: ./lab2/all_img/2010_005874.jpg
#   inflating: ./lab2/all_img/2010_001070.jpg
#   inflating: ./lab2/all_img/007133.jpg
#   inflating: ./lab2/all_img/2009_000770.jpg
#   inflating: ./lab2/all_img/2009_001195.jpg
#   inflating: ./lab2/all_img/2009_001321.jpg
#   inflating: ./lab2/all_img/2008_001871.jpg
#   inflating: ./lab2/all_img/2011_001841.jpg
#   inflating: ./lab2/all_img/008784.jpg
#   inflating: ./lab2/all_img/2010_000947.jpg
#   inflating: ./lab2/all_img/2011_002612.jpg
#   inflating: ./lab2/all_img/2010_003465.jpg
#   inflating: ./lab2/all_img/2008_007279.jpg
#   inflating: ./lab2/all_img/2010_005974.jpg
#   inflating: ./lab2/all_img/2008_007456.jpg
#   inflating: ./lab2/all_img/005470.jpg
#   inflating: ./lab2/all_img/003814.jpg
#   inflating: ./lab2/all_img/2010_003147.jpg
#   inflating: ./lab2/all_img/2010_002187.jpg
#   inflating: ./lab2/all_img/003792.jpg
#   inflating: ./lab2/all_img/2009_005036.jpg
#   inflating: ./lab2/all_img/2008_002673.jpg
#   inflating: ./lab2/all_img/2008_002749.jpg
#   inflating: ./lab2/all_img/2008_003932.jpg
#   inflating: ./lab2/all_img/001636.jpg
#   inflating: ./lab2/all_img/008980.jpg
#   inflating: ./lab2/all_img/2010_005216.jpg
#   inflating: ./lab2/all_img/001436.jpg
#   inflating: ./lab2/all_img/2010_000488.jpg
#   inflating: ./lab2/all_img/2010_000458.jpg
#   inflating: ./lab2/all_img/001237.jpg
#   inflating: ./lab2/all_img/2009_000869.jpg
#   inflating: ./lab2/all_img/2008_006522.jpg
#   inflating: ./lab2/all_img/2010_003365.jpg
#   inflating: ./lab2/all_img/004351.jpg
#   inflating: ./lab2/all_img/2010_000079.jpg
#   inflating: ./lab2/all_img/2010_004807.jpg
#   inflating: ./lab2/all_img/2011_002114.jpg
#   inflating: ./lab2/all_img/007003.jpg
#   inflating: ./lab2/all_img/007486.jpg
#   inflating: ./lab2/all_img/2008_008570.jpg
#   inflating: ./lab2/all_img/2008_007353.jpg
#   inflating: ./lab2/all_img/008372.jpg
#   inflating: ./lab2/all_img/2011_002930.jpg
#   inflating: ./lab2/all_img/006058.jpg
#   inflating: ./lab2/all_img/2009_002176.jpg
#   inflating: ./lab2/all_img/2008_006781.jpg
#   inflating: ./lab2/all_img/2009_002808.jpg
#   inflating: ./lab2/all_img/008296.jpg
#   inflating: ./lab2/all_img/2010_004558.jpg
#   inflating: ./lab2/all_img/2008_005379.jpg
#   inflating: ./lab2/all_img/009729.jpg
#   inflating: ./lab2/all_img/001888.jpg
#   inflating: ./lab2/all_img/003658.jpg
#   inflating: ./lab2/all_img/003243.jpg
#   inflating: ./lab2/all_img/2009_002259.jpg
#   inflating: ./lab2/all_img/000537.jpg
#   inflating: ./lab2/all_img/002466.jpg
#   inflating: ./lab2/all_img/000317.jpg
#   inflating: ./lab2/all_img/2009_004877.jpg
#   inflating: ./lab2/all_img/2011_001541.jpg
#   inflating: ./lab2/all_img/2009_003644.jpg
#   inflating: ./lab2/all_img/2009_003018.jpg
#   inflating: ./lab2/all_img/2008_004767.jpg
#   inflating: ./lab2/all_img/2008_004630.jpg
#   inflating: ./lab2/all_img/2008_003926.jpg
#   inflating: ./lab2/all_img/2008_002710.jpg
#   inflating: ./lab2/all_img/2010_003686.jpg
#   inflating: ./lab2/all_img/001316.jpg
#   inflating: ./lab2/all_img/2010_004370.jpg
#   inflating: ./lab2/all_img/2009_002914.jpg
#   inflating: ./lab2/all_img/2008_004306.jpg
#   inflating: ./lab2/all_img/000720.jpg
#   inflating: ./lab2/all_img/2008_003659.jpg
#   inflating: ./lab2/all_img/2008_006049.jpg
#   inflating: ./lab2/all_img/2008_003974.jpg
#   inflating: ./lab2/all_img/005524.jpg
#   inflating: ./lab2/all_img/2008_006417.jpg
#   inflating: ./lab2/all_img/007058.jpg
#   inflating: ./lab2/all_img/2009_003138.jpg
#   inflating: ./lab2/all_img/2008_002410.jpg
#   inflating: ./lab2/all_img/006512.jpg
#   inflating: ./lab2/all_img/2008_002444.jpg
#   inflating: ./lab2/all_img/2009_003928.jpg
#   inflating: ./lab2/all_img/005199.jpg
#   inflating: ./lab2/all_img/007071.jpg
#   inflating: ./lab2/all_img/007223.jpg
#   inflating: ./lab2/all_img/000268.jpg
#   inflating: ./lab2/all_img/001239.jpg
#   inflating: ./lab2/all_img/2007_001774.jpg
#   inflating: ./lab2/all_img/007474.jpg
#   inflating: ./lab2/all_img/2011_001480.jpg
#   inflating: ./lab2/all_img/000528.jpg
#   inflating: ./lab2/all_img/001618.jpg
#   inflating: ./lab2/all_img/2008_004402.jpg
#   inflating: ./lab2/all_img/007038.jpg
#   inflating: ./lab2/all_img/2008_002845.jpg
#   inflating: ./lab2/all_img/2010_001009.jpg
#   inflating: ./lab2/all_img/2008_000304.jpg
#   inflating: ./lab2/all_img/2009_002299.jpg
#   inflating: ./lab2/all_img/006162.jpg
#   inflating: ./lab2/all_img/2010_004865.jpg
#   inflating: ./lab2/all_img/2010_000392.jpg
#   inflating: ./lab2/all_img/007280.jpg
#   inflating: ./lab2/all_img/2010_004919.jpg
#   inflating: ./lab2/all_img/2010_002456.jpg
#   inflating: ./lab2/all_img/000768.jpg
#   inflating: ./lab2/all_img/2009_000964.jpg
#   inflating: ./lab2/all_img/2010_001497.jpg
#   inflating: ./lab2/all_img/004977.jpg
#   inflating: ./lab2/all_img/2008_003704.jpg
#   inflating: ./lab2/all_img/003165.jpg
#   inflating: ./lab2/all_img/001360.jpg
#   inflating: ./lab2/all_img/2008_008028.jpg
#   inflating: ./lab2/all_img/2008_006999.jpg
#   inflating: ./lab2/all_img/002690.jpg
#   inflating: ./lab2/all_img/007968.jpg
#   inflating: ./lab2/all_img/2010_005935.jpg
#   inflating: ./lab2/all_img/2008_000062.jpg
#   inflating: ./lab2/all_img/002699.jpg
#   inflating: ./lab2/all_img/2010_005462.jpg
#   inflating: ./lab2/all_img/2010_004484.jpg
#   inflating: ./lab2/all_img/2010_001744.jpg
#   inflating: ./lab2/all_img/006940.jpg
#   inflating: ./lab2/all_img/2009_003601.jpg
#   inflating: ./lab2/all_img/2008_003261.jpg
#   inflating: ./lab2/all_img/005071.jpg
#   inflating: ./lab2/all_img/2008_004163.jpg
#   inflating: ./lab2/all_img/2008_007106.jpg
#   inflating: ./lab2/all_img/2008_000863.jpg
#   inflating: ./lab2/all_img/001676.jpg
#   inflating: ./lab2/all_img/2010_003139.jpg
#   inflating: ./lab2/all_img/009810.jpg
#   inflating: ./lab2/all_img/2010_005886.jpg
#   inflating: ./lab2/all_img/2008_004662.jpg
#   inflating: ./lab2/all_img/2009_001052.jpg
#   inflating: ./lab2/all_img/2008_002454.jpg
#   inflating: ./lab2/all_img/2007_003000.jpg
#   inflating: ./lab2/all_img/2010_005167.jpg
#   inflating: ./lab2/all_img/2009_002592.jpg
#   inflating: ./lab2/all_img/2010_003522.jpg
#   inflating: ./lab2/all_img/004632.jpg
#   inflating: ./lab2/all_img/2010_005973.jpg
#   inflating: ./lab2/all_img/2010_005943.jpg
#   inflating: ./lab2/all_img/006893.jpg
#   inflating: ./lab2/all_img/2010_002029.jpg
#   inflating: ./lab2/all_img/2009_000985.jpg
#   inflating: ./lab2/all_img/002109.jpg
#   inflating: ./lab2/all_img/001281.jpg
#   inflating: ./lab2/all_img/2009_000566.jpg
#   inflating: ./lab2/all_img/2010_003958.jpg
#   inflating: ./lab2/all_img/007731.jpg
#   inflating: ./lab2/all_img/2009_000862.jpg
#   inflating: ./lab2/all_img/002677.jpg
#   inflating: ./lab2/all_img/005901.jpg
#   inflating: ./lab2/all_img/005609.jpg
#   inflating: ./lab2/all_img/002095.jpg
#   inflating: ./lab2/all_img/2008_005989.jpg
#   inflating: ./lab2/all_img/2010_006076.jpg
#   inflating: ./lab2/all_img/006212.jpg
#   inflating: ./lab2/all_img/2009_003309.jpg
#   inflating: ./lab2/all_img/2009_003916.jpg
#   inflating: ./lab2/all_img/2009_000625.jpg
#   inflating: ./lab2/all_img/005888.jpg
#   inflating: ./lab2/all_img/2008_003572.jpg
#   inflating: ./lab2/all_img/009029.jpg
#   inflating: ./lab2/all_img/2010_001572.jpg
#   inflating: ./lab2/all_img/2010_001118.jpg
#   inflating: ./lab2/all_img/2010_000065.jpg
#   inflating: ./lab2/all_img/002006.jpg
#   inflating: ./lab2/all_img/2009_002862.jpg
#   inflating: ./lab2/all_img/2010_000009.jpg
#   inflating: ./lab2/all_img/2011_000116.jpg
#   inflating: ./lab2/all_img/2008_000804.jpg
#   inflating: ./lab2/all_img/2008_003443.jpg
#   inflating: ./lab2/all_img/2007_006581.jpg
#   inflating: ./lab2/all_img/2010_000572.jpg
#   inflating: ./lab2/all_img/2008_005194.jpg
#   inflating: ./lab2/all_img/2010_000194.jpg
#   inflating: ./lab2/all_img/2009_003524.jpg
#   inflating: ./lab2/all_img/2008_006335.jpg
#   inflating: ./lab2/all_img/2009_002609.jpg
#   inflating: ./lab2/all_img/2008_007295.jpg
#   inflating: ./lab2/all_img/003606.jpg
#   inflating: ./lab2/all_img/007958.jpg
#   inflating: ./lab2/all_img/006096.jpg
#   inflating: ./lab2/all_img/001148.jpg
#   inflating: ./lab2/all_img/2010_000157.jpg
#   inflating: ./lab2/all_img/2009_002910.jpg
#   inflating: ./lab2/all_img/2009_000631.jpg
#   inflating: ./lab2/all_img/000609.jpg
#   inflating: ./lab2/all_img/2008_005382.jpg
#   inflating: ./lab2/all_img/2008_002225.jpg
#   inflating: ./lab2/all_img/009042.jpg
#   inflating: ./lab2/all_img/2009_001374.jpg
#   inflating: ./lab2/all_img/2011_000901.jpg
#   inflating: ./lab2/all_img/2008_005728.jpg
#   inflating: ./lab2/all_img/000190.jpg
#   inflating: ./lab2/all_img/2010_000043.jpg
#   inflating: ./lab2/all_img/2008_007118.jpg
#   inflating: ./lab2/all_img/006766.jpg
#   inflating: ./lab2/all_img/003890.jpg
#   inflating: ./lab2/all_img/2008_007786.jpg
#   inflating: ./lab2/all_img/2011_002284.jpg
#   inflating: ./lab2/all_img/2010_003974.jpg
#   inflating: ./lab2/all_img/000131.jpg
#   inflating: ./lab2/all_img/2008_008043.jpg
#   inflating: ./lab2/all_img/002420.jpg
#   inflating: ./lab2/all_img/000494.jpg
#   inflating: ./lab2/all_img/2010_002778.jpg
#   inflating: ./lab2/all_img/2009_005119.jpg
#   inflating: ./lab2/all_img/2010_003300.jpg
#   inflating: ./lab2/all_img/2007_002281.jpg
#   inflating: ./lab2/all_img/2008_006538.jpg
#   inflating: ./lab2/all_img/008747.jpg
#   inflating: ./lab2/all_img/2008_000401.jpg
#   inflating: ./lab2/all_img/2010_004575.jpg
#   inflating: ./lab2/all_img/2010_003400.jpg
#   inflating: ./lab2/all_img/2007_001825.jpg
#   inflating: ./lab2/all_img/2010_004518.jpg
#   inflating: ./lab2/all_img/2009_001260.jpg
#   inflating: ./lab2/all_img/2009_001706.jpg
#   inflating: ./lab2/all_img/2009_005051.jpg
#   inflating: ./lab2/all_img/2010_005854.jpg
#   inflating: ./lab2/all_img/004434.jpg
#   inflating: ./lab2/all_img/2008_005673.jpg
#   inflating: ./lab2/all_img/002875.jpg
#   inflating: ./lab2/all_img/005559.jpg
#   inflating: ./lab2/all_img/2008_008092.jpg
#   inflating: ./lab2/all_img/2008_005288.jpg
#   inflating: ./lab2/all_img/000060.jpg
#   inflating: ./lab2/all_img/008822.jpg
#   inflating: ./lab2/all_img/2011_001028.jpg
#   inflating: ./lab2/all_img/003194.jpg
#   inflating: ./lab2/all_img/2010_001100.jpg
#   inflating: ./lab2/all_img/005121.jpg
#   inflating: ./lab2/all_img/2007_007930.jpg
#   inflating: ./lab2/all_img/003786.jpg
#   inflating: ./lab2/all_img/2009_005133.jpg
#   inflating: ./lab2/all_img/2009_005162.jpg
#   inflating: ./lab2/all_img/006305.jpg
#   inflating: ./lab2/all_img/2008_007507.jpg
#   inflating: ./lab2/all_img/2010_004129.jpg
#   inflating: ./lab2/all_img/2008_004559.jpg
#   inflating: ./lab2/all_img/2008_008508.jpg
#   inflating: ./lab2/all_img/2010_001402.jpg
#   inflating: ./lab2/all_img/2007_002470.jpg
#   inflating: ./lab2/all_img/002956.jpg
#   inflating: ./lab2/all_img/001638.jpg
#   inflating: ./lab2/all_img/2009_001612.jpg
#   inflating: ./lab2/all_img/007322.jpg
#   inflating: ./lab2/all_img/007916.jpg
#   inflating: ./lab2/all_img/2009_001915.jpg
#   inflating: ./lab2/all_img/2008_001111.jpg
#   inflating: ./lab2/all_img/2010_000303.jpg
#   inflating: ./lab2/all_img/004992.jpg
#   inflating: ./lab2/all_img/005003.jpg
#   inflating: ./lab2/all_img/2008_005036.jpg
#   inflating: ./lab2/all_img/2011_000312.jpg
#   inflating: ./lab2/all_img/2009_001674.jpg
#   inflating: ./lab2/all_img/2007_000720.jpg
#   inflating: ./lab2/all_img/007854.jpg
#   inflating: ./lab2/all_img/003596.jpg
#   inflating: ./lab2/all_img/002373.jpg
#   inflating: ./lab2/all_img/2008_006956.jpg
#   inflating: ./lab2/all_img/2010_003333.jpg
#   inflating: ./lab2/all_img/2008_004653.jpg
#   inflating: ./lab2/all_img/006597.jpg
#   inflating: ./lab2/all_img/004129.jpg
#   inflating: ./lab2/all_img/006174.jpg
#   inflating: ./lab2/all_img/008667.jpg
#   inflating: ./lab2/all_img/2009_000354.jpg
#   inflating: ./lab2/all_img/000501.jpg
#   inflating: ./lab2/all_img/000036.jpg
#   inflating: ./lab2/all_img/003820.jpg
#   inflating: ./lab2/all_img/2009_001678.jpg
#   inflating: ./lab2/all_img/2008_000901.jpg
#   inflating: ./lab2/all_img/2010_002805.jpg
#   inflating: ./lab2/all_img/2010_002963.jpg
#   inflating: ./lab2/all_img/2010_000480.jpg
#   inflating: ./lab2/all_img/2008_006600.jpg
#   inflating: ./lab2/all_img/2008_006178.jpg
#   inflating: ./lab2/all_img/2010_003179.jpg
#   inflating: ./lab2/all_img/2011_000569.jpg
#   inflating: ./lab2/all_img/2010_002143.jpg
#   inflating: ./lab2/all_img/2010_003598.jpg
#   inflating: ./lab2/all_img/2008_008446.jpg
#   inflating: ./lab2/all_img/2009_004829.jpg
#   inflating: ./lab2/all_img/2010_000031.jpg
#   inflating: ./lab2/all_img/2008_004722.jpg
#   inflating: ./lab2/all_img/2010_003060.jpg
#   inflating: ./lab2/all_img/2009_003056.jpg
#   inflating: ./lab2/all_img/2008_006394.jpg
#   inflating: ./lab2/all_img/002994.jpg
#   inflating: ./lab2/all_img/2008_008585.jpg
#   inflating: ./lab2/all_img/009406.jpg
#   inflating: ./lab2/all_img/009461.jpg
#   inflating: ./lab2/all_img/2008_003423.jpg
#   inflating: ./lab2/all_img/2009_000782.jpg
#   inflating: ./lab2/all_img/2008_007095.jpg
#   inflating: ./lab2/all_img/2009_000320.jpg
#   inflating: ./lab2/all_img/2010_000248.jpg
#   inflating: ./lab2/all_img/2009_005120.jpg
#   inflating: ./lab2/all_img/2010_000254.jpg
#   inflating: ./lab2/all_img/008450.jpg
#   inflating: ./lab2/all_img/2009_001027.jpg
#   inflating: ./lab2/all_img/2011_000176.jpg
#   inflating: ./lab2/all_img/001290.jpg
#   inflating: ./lab2/all_img/006994.jpg
#    creating: ./lab2/.ipynb_checkpoints/
#   inflating: ./lab2/util.py
#   inflating: ./lab2/pre_train.pt

# %%
file_root = './lab2/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./lab2/utils/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('./lab2/pre_train.pt')
#print(state_dict)
#print(state_dict["state_dict"])
model.load_state_dict(state_dict['state_dict'])


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# <ipython-input-54-dd7573c6661d>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load('./lab2/pre_train.pt')
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:501.4312, average_loss: 420.4568
# Epoch [1/15], Iter [20,430] Loss:93.1827, average_loss: 310.5832
# Epoch [1/15], Iter [30,430] Loss:78.8100, average_loss: 230.9153
# Epoch [1/15], Iter [40,430] Loss:17.4371, average_loss: 184.8097
# Epoch [1/15], Iter [50,430] Loss:16.5721, average_loss: 152.4533
# Epoch [1/15], Iter [60,430] Loss:5.6141, average_loss: 128.6573
# Epoch [1/15], Iter [70,430] Loss:5.6893, average_loss: 111.4244
# Epoch [1/15], Iter [80,430] Loss:4.3524, average_loss: 98.2083
# Epoch [1/15], Iter [90,430] Loss:8.6310, average_loss: 87.8900
# Epoch [1/15], Iter [100,430] Loss:3.2679, average_loss: 79.5874
# Epoch [1/15], Iter [110,430] Loss:5.3176, average_loss: 72.7588
# Epoch [1/15], Iter [120,430] Loss:5.6312, average_loss: 67.0520
# Epoch [1/15], Iter [130,430] Loss:3.0881, average_loss: 62.1731
# Epoch [1/15], Iter [140,430] Loss:2.9103, average_loss: 58.0005
# Epoch [1/15], Iter [150,430] Loss:4.5491, average_loss: 54.3698
# Epoch [1/15], Iter [160,430] Loss:5.8386, average_loss: 51.2687
# Epoch [1/15], Iter [170,430] Loss:5.8645, average_loss: 48.5033
# Epoch [1/15], Iter [180,430] Loss:3.1921, average_loss: 45.9972
# Epoch [1/15], Iter [190,430] Loss:3.5651, average_loss: 43.7681
# Epoch [1/15], Iter [200,430] Loss:3.5753, average_loss: 41.7512
# Epoch [1/15], Iter [210,430] Loss:3.7433, average_loss: 39.9520
# Epoch [1/15], Iter [220,430] Loss:3.9956, average_loss: 38.3001
# Epoch [1/15], Iter [230,430] Loss:4.3348, average_loss: 36.8055
# Epoch [1/15], Iter [240,430] Loss:2.5432, average_loss: 35.4284
# Epoch [1/15], Iter [250,430] Loss:4.3753, average_loss: 34.1710
# Epoch [1/15], Iter [260,430] Loss:2.4838, average_loss: 32.9946
# Epoch [1/15], Iter [270,430] Loss:3.1674, average_loss: 31.9626
# Epoch [1/15], Iter [280,430] Loss:3.5151, average_loss: 30.9613
# Epoch [1/15], Iter [290,430] Loss:3.6031, average_loss: 30.0354
# Epoch [1/15], Iter [300,430] Loss:3.0377, average_loss: 29.1763
# Epoch [1/15], Iter [310,430] Loss:3.6837, average_loss: 28.3474
# Epoch [1/15], Iter [320,430] Loss:2.4298, average_loss: 27.5949
# Epoch [1/15], Iter [330,430] Loss:3.7445, average_loss: 26.8654
# Epoch [1/15], Iter [340,430] Loss:3.8282, average_loss: 26.1705
# Epoch [1/15], Iter [350,430] Loss:3.2500, average_loss: 25.5437
# Epoch [1/15], Iter [360,430] Loss:2.0785, average_loss: 24.9305
# Epoch [1/15], Iter [370,430] Loss:3.3689, average_loss: 24.3528
# Epoch [1/15], Iter [380,430] Loss:3.6404, average_loss: 23.8154
# Epoch [1/15], Iter [390,430] Loss:3.0621, average_loss: 23.2868
# Epoch [1/15], Iter [400,430] Loss:3.1280, average_loss: 22.7977
# Epoch [1/15], Iter [410,430] Loss:6.9526, average_loss: 22.3512
# Epoch [1/15], Iter [420,430] Loss:3.0773, average_loss: 21.9147
# Epoch [1/15], Iter [430,430] Loss:2.5512, average_loss: 21.4876
# Epoch [2/15], Iter [10,430] Loss:2.9562, average_loss: 3.7821
# Epoch [2/15], Iter [20,430] Loss:3.9476, average_loss: 3.9892
# Epoch [2/15], Iter [30,430] Loss:3.8661, average_loss: 3.8238
# Epoch [2/15], Iter [40,430] Loss:3.8863, average_loss: 3.7205
# Epoch [2/15], Iter [50,430] Loss:2.6909, average_loss: 3.7008
# Epoch [2/15], Iter [60,430] Loss:3.0352, average_loss: 3.6754
# Epoch [2/15], Iter [70,430] Loss:3.8217, average_loss: 3.7017
# Epoch [2/15], Iter [80,430] Loss:4.9302, average_loss: 3.7017
# Epoch [2/15], Iter [90,430] Loss:3.7463, average_loss: 3.6894
# Epoch [2/15], Iter [100,430] Loss:2.4023, average_loss: 3.6466
# Epoch [2/15], Iter [110,430] Loss:4.3253, average_loss: 3.6132
# Epoch [2/15], Iter [120,430] Loss:3.3666, average_loss: 3.5980
# Epoch [2/15], Iter [130,430] Loss:3.1238, average_loss: 3.5799
# Epoch [2/15], Iter [140,430] Loss:3.2080, average_loss: 3.5814
# Epoch [2/15], Iter [150,430] Loss:6.7621, average_loss: 3.6000
# Epoch [2/15], Iter [160,430] Loss:2.4176, average_loss: 3.5912
# Epoch [2/15], Iter [170,430] Loss:2.2032, average_loss: 3.5763
# Epoch [2/15], Iter [180,430] Loss:2.8706, average_loss: 3.5496
# Epoch [2/15], Iter [190,430] Loss:5.3284, average_loss: 3.5812
# Epoch [2/15], Iter [200,430] Loss:3.5622, average_loss: 3.5697
# Epoch [2/15], Iter [210,430] Loss:3.4791, average_loss: 3.5755
# Epoch [2/15], Iter [220,430] Loss:3.1906, average_loss: 3.5762
# Epoch [2/15], Iter [230,430] Loss:3.4282, average_loss: 3.5655
# Epoch [2/15], Iter [240,430] Loss:2.6386, average_loss: 3.5603
# Epoch [2/15], Iter [250,430] Loss:4.3966, average_loss: 3.5589
# Epoch [2/15], Iter [260,430] Loss:2.4317, average_loss: 3.5504
# Epoch [2/15], Iter [270,430] Loss:2.3184, average_loss: 3.5372
# Epoch [2/15], Iter [280,430] Loss:2.8159, average_loss: 3.5439
# Epoch [2/15], Iter [290,430] Loss:2.8247, average_loss: 3.5444
# Epoch [2/15], Iter [300,430] Loss:2.2733, average_loss: 3.5374
# Epoch [2/15], Iter [310,430] Loss:3.6834, average_loss: 3.5534
# Epoch [2/15], Iter [320,430] Loss:2.2501, average_loss: 3.5562
# Epoch [2/15], Iter [330,430] Loss:5.0801, average_loss: 3.5722
# Epoch [2/15], Iter [340,430] Loss:3.8790, average_loss: 3.5637
# Epoch [2/15], Iter [350,430] Loss:3.5381, average_loss: 3.5615
# Epoch [2/15], Iter [360,430] Loss:3.1792, average_loss: 3.5576
# Epoch [2/15], Iter [370,430] Loss:3.2687, average_loss: 3.5560
# Epoch [2/15], Iter [380,430] Loss:3.0030, average_loss: 3.5469
# Epoch [2/15], Iter [390,430] Loss:3.0119, average_loss: 3.5505
# Epoch [2/15], Iter [400,430] Loss:2.8259, average_loss: 3.5496
# Epoch [2/15], Iter [410,430] Loss:3.4949, average_loss: 3.5431
# Epoch [2/15], Iter [420,430] Loss:3.1033, average_loss: 3.5481
# Epoch [2/15], Iter [430,430] Loss:3.8877, average_loss: 3.5596
# Epoch [3/15], Iter [10,430] Loss:4.2233, average_loss: 3.3598
# Epoch [3/15], Iter [20,430] Loss:5.4132, average_loss: 3.7049
# Epoch [3/15], Iter [30,430] Loss:2.6467, average_loss: 3.7756
# Epoch [3/15], Iter [40,430] Loss:3.4332, average_loss: 3.6304
# Epoch [3/15], Iter [50,430] Loss:4.1941, average_loss: 3.5862
# Epoch [3/15], Iter [60,430] Loss:3.4041, average_loss: 3.6710
# Epoch [3/15], Iter [70,430] Loss:4.3336, average_loss: 3.6869
# Epoch [3/15], Iter [80,430] Loss:3.7188, average_loss: 3.6464
# Epoch [3/15], Iter [90,430] Loss:3.4086, average_loss: 3.6397
# Epoch [3/15], Iter [100,430] Loss:4.7009, average_loss: 3.6679
# Epoch [3/15], Iter [110,430] Loss:5.6308, average_loss: 3.7151
# Epoch [3/15], Iter [120,430] Loss:2.9800, average_loss: 3.7058
# Epoch [3/15], Iter [130,430] Loss:3.1990, average_loss: 3.6900
# Epoch [3/15], Iter [140,430] Loss:2.8529, average_loss: 3.6789
# Epoch [3/15], Iter [150,430] Loss:5.7699, average_loss: 3.6610
# Epoch [3/15], Iter [160,430] Loss:2.6131, average_loss: 3.6358
# Epoch [3/15], Iter [170,430] Loss:4.7028, average_loss: 3.6529
# Epoch [3/15], Iter [180,430] Loss:3.1630, average_loss: 3.6651
# Epoch [3/15], Iter [190,430] Loss:2.9504, average_loss: 3.6381
# Epoch [3/15], Iter [200,430] Loss:4.2990, average_loss: 3.6546
# Epoch [3/15], Iter [210,430] Loss:6.8722, average_loss: 3.6908
# Epoch [3/15], Iter [220,430] Loss:2.7327, average_loss: 3.6938
# Epoch [3/15], Iter [230,430] Loss:2.4780, average_loss: 3.6935
# Epoch [3/15], Iter [240,430] Loss:4.6339, average_loss: 3.7191
# Epoch [3/15], Iter [250,430] Loss:3.9829, average_loss: 3.7172
# Epoch [3/15], Iter [260,430] Loss:2.9950, average_loss: 3.7006
# Epoch [3/15], Iter [270,430] Loss:3.4654, average_loss: 3.7180
# Epoch [3/15], Iter [280,430] Loss:4.4627, average_loss: 3.7259
# Epoch [3/15], Iter [290,430] Loss:4.9470, average_loss: 3.7121
# Epoch [3/15], Iter [300,430] Loss:3.8391, average_loss: 3.7099
# Epoch [3/15], Iter [310,430] Loss:5.7462, average_loss: 3.7161
# Epoch [3/15], Iter [320,430] Loss:3.8902, average_loss: 3.7308
# Epoch [3/15], Iter [330,430] Loss:2.8013, average_loss: 3.7184
# Epoch [3/15], Iter [340,430] Loss:2.6058, average_loss: 3.7266
# Epoch [3/15], Iter [350,430] Loss:3.7413, average_loss: 3.7238
# Epoch [3/15], Iter [360,430] Loss:2.5147, average_loss: 3.7184
# Epoch [3/15], Iter [370,430] Loss:3.5422, average_loss: 3.7339
# Epoch [3/15], Iter [380,430] Loss:2.7380, average_loss: 3.7115
# Epoch [3/15], Iter [390,430] Loss:5.0248, average_loss: 3.7065
# Epoch [3/15], Iter [400,430] Loss:2.9783, average_loss: 3.7021
# Epoch [3/15], Iter [410,430] Loss:7.1109, average_loss: 3.7112
# Epoch [3/15], Iter [420,430] Loss:2.7422, average_loss: 3.7047
# Epoch [3/15], Iter [430,430] Loss:2.6049, average_loss: 3.7075
# Epoch [4/15], Iter [10,430] Loss:2.9118, average_loss: 3.6017
# Epoch [4/15], Iter [20,430] Loss:4.0531, average_loss: 3.6567
# Epoch [4/15], Iter [30,430] Loss:3.1546, average_loss: 3.6903
# Epoch [4/15], Iter [40,430] Loss:2.6477, average_loss: 3.6041
# Epoch [4/15], Iter [50,430] Loss:3.5057, average_loss: 3.6564
# Epoch [4/15], Iter [60,430] Loss:4.1383, average_loss: 3.6925
# Epoch [4/15], Iter [70,430] Loss:2.3064, average_loss: 3.6697
# Epoch [4/15], Iter [80,430] Loss:3.0333, average_loss: 3.6636
# Epoch [4/15], Iter [90,430] Loss:3.3335, average_loss: 3.6445
# Epoch [4/15], Iter [100,430] Loss:3.5231, average_loss: 3.6363
# Epoch [4/15], Iter [110,430] Loss:2.9008, average_loss: 3.6187
# Epoch [4/15], Iter [120,430] Loss:4.0906, average_loss: 3.5793
# Epoch [4/15], Iter [130,430] Loss:1.6613, average_loss: 3.5917
# Epoch [4/15], Iter [140,430] Loss:4.6459, average_loss: 3.6386
# Epoch [4/15], Iter [150,430] Loss:3.8001, average_loss: 3.6713
# Epoch [4/15], Iter [160,430] Loss:2.1449, average_loss: 3.6449
# Epoch [4/15], Iter [170,430] Loss:3.8934, average_loss: 3.6201
# Epoch [4/15], Iter [180,430] Loss:2.5238, average_loss: 3.6032
# Epoch [4/15], Iter [190,430] Loss:3.3234, average_loss: 3.6059
# Epoch [4/15], Iter [200,430] Loss:3.0022, average_loss: 3.6317
# Epoch [4/15], Iter [210,430] Loss:3.4061, average_loss: 3.6412
# Epoch [4/15], Iter [220,430] Loss:3.4471, average_loss: 3.6310
# Epoch [4/15], Iter [230,430] Loss:4.1992, average_loss: 3.6161
# Epoch [4/15], Iter [240,430] Loss:3.3199, average_loss: 3.6085
# Epoch [4/15], Iter [250,430] Loss:2.3734, average_loss: 3.6107
# Epoch [4/15], Iter [260,430] Loss:3.6182, average_loss: 3.6436
# Epoch [4/15], Iter [270,430] Loss:3.3020, average_loss: 3.6427
# Epoch [4/15], Iter [280,430] Loss:3.7627, average_loss: 3.6408
# Epoch [4/15], Iter [290,430] Loss:2.7082, average_loss: 3.6386
# Epoch [4/15], Iter [300,430] Loss:3.0665, average_loss: 3.6185
# Epoch [4/15], Iter [310,430] Loss:3.8094, average_loss: 3.6095
# Epoch [4/15], Iter [320,430] Loss:3.3939, average_loss: 3.5996
# Epoch [4/15], Iter [330,430] Loss:3.1871, average_loss: 3.5880
# Epoch [4/15], Iter [340,430] Loss:3.2921, average_loss: 3.5797
# Epoch [4/15], Iter [350,430] Loss:2.4276, average_loss: 3.5808
# Epoch [4/15], Iter [360,430] Loss:2.7413, average_loss: 3.5943
# Epoch [4/15], Iter [370,430] Loss:2.8197, average_loss: 3.6004
# Epoch [4/15], Iter [380,430] Loss:2.5839, average_loss: 3.5993
# Epoch [4/15], Iter [390,430] Loss:5.0448, average_loss: 3.5932
# Epoch [4/15], Iter [400,430] Loss:2.0525, average_loss: 3.5886
# Epoch [4/15], Iter [410,430] Loss:3.7847, average_loss: 3.5895
# Epoch [4/15], Iter [420,430] Loss:3.6406, average_loss: 3.5931
# Epoch [4/15], Iter [430,430] Loss:3.4032, average_loss: 3.5952
# Epoch [5/15], Iter [10,430] Loss:6.0500, average_loss: 3.8982
# Epoch [5/15], Iter [20,430] Loss:2.8312, average_loss: 3.7369
# Epoch [5/15], Iter [30,430] Loss:3.2509, average_loss: 3.6734
# Epoch [5/15], Iter [40,430] Loss:5.6792, average_loss: 3.6526
# Epoch [5/15], Iter [50,430] Loss:5.4048, average_loss: 3.6126
# Epoch [5/15], Iter [60,430] Loss:2.3624, average_loss: 3.4999
# Epoch [5/15], Iter [70,430] Loss:3.6740, average_loss: 3.5126
# Epoch [5/15], Iter [80,430] Loss:4.1403, average_loss: 3.4868
# Epoch [5/15], Iter [90,430] Loss:4.3954, average_loss: 3.5409
# Epoch [5/15], Iter [100,430] Loss:3.3199, average_loss: 3.5577
# Epoch [5/15], Iter [110,430] Loss:3.3214, average_loss: 3.5552
# Epoch [5/15], Iter [120,430] Loss:4.3541, average_loss: 3.5678
# Epoch [5/15], Iter [130,430] Loss:7.9087, average_loss: 3.5899
# Epoch [5/15], Iter [140,430] Loss:2.7957, average_loss: 3.5746
# Epoch [5/15], Iter [150,430] Loss:3.3946, average_loss: 3.5625
# Epoch [5/15], Iter [160,430] Loss:4.0623, average_loss: 3.5453
# Epoch [5/15], Iter [170,430] Loss:4.1387, average_loss: 3.5377
# Epoch [5/15], Iter [180,430] Loss:3.4704, average_loss: 3.5285
# Epoch [5/15], Iter [190,430] Loss:2.8765, average_loss: 3.5185
# Epoch [5/15], Iter [200,430] Loss:3.2728, average_loss: 3.5202
# Epoch [5/15], Iter [210,430] Loss:5.1996, average_loss: 3.5398
# Epoch [5/15], Iter [220,430] Loss:3.4948, average_loss: 3.5226
# Epoch [5/15], Iter [230,430] Loss:3.6963, average_loss: 3.5361
# Epoch [5/15], Iter [240,430] Loss:7.5572, average_loss: 3.5430
# Epoch [5/15], Iter [250,430] Loss:4.0487, average_loss: 3.5449
# Epoch [5/15], Iter [260,430] Loss:2.8260, average_loss: 3.5504
# Epoch [5/15], Iter [270,430] Loss:4.5034, average_loss: 3.5624
# Epoch [5/15], Iter [280,430] Loss:3.4088, average_loss: 3.5499
# Epoch [5/15], Iter [290,430] Loss:3.3481, average_loss: 3.5459
# Epoch [5/15], Iter [300,430] Loss:2.9831, average_loss: 3.5564
# Epoch [5/15], Iter [310,430] Loss:2.2454, average_loss: 3.5533
# Epoch [5/15], Iter [320,430] Loss:4.8275, average_loss: 3.5692
# Epoch [5/15], Iter [330,430] Loss:2.9671, average_loss: 3.5666
# Epoch [5/15], Iter [340,430] Loss:5.7661, average_loss: 3.5751
# Epoch [5/15], Iter [350,430] Loss:4.0443, average_loss: 3.5682
# Epoch [5/15], Iter [360,430] Loss:4.7391, average_loss: 3.5755
# Epoch [5/15], Iter [370,430] Loss:3.4916, average_loss: 3.5676
# Epoch [5/15], Iter [380,430] Loss:2.7713, average_loss: 3.5620
# Epoch [5/15], Iter [390,430] Loss:3.5044, average_loss: 3.5460
# Epoch [5/15], Iter [400,430] Loss:2.0872, average_loss: 3.5425
# Epoch [5/15], Iter [410,430] Loss:3.6723, average_loss: 3.5555
# Epoch [5/15], Iter [420,430] Loss:2.4983, average_loss: 3.5549
# Epoch [5/15], Iter [430,430] Loss:2.7644, average_loss: 3.5438
# Epoch [6/15], Iter [10,430] Loss:4.4287, average_loss: 3.3177
# Epoch [6/15], Iter [20,430] Loss:2.0802, average_loss: 3.5708
# Epoch [6/15], Iter [30,430] Loss:4.1548, average_loss: 3.4756
# Epoch [6/15], Iter [40,430] Loss:1.8016, average_loss: 3.3584
# Epoch [6/15], Iter [50,430] Loss:4.0837, average_loss: 3.3187
# Epoch [6/15], Iter [60,430] Loss:1.8591, average_loss: 3.2713
# Epoch [6/15], Iter [70,430] Loss:2.9394, average_loss: 3.2711
# Epoch [6/15], Iter [80,430] Loss:2.0521, average_loss: 3.2910
# Epoch [6/15], Iter [90,430] Loss:2.9973, average_loss: 3.3192
# Epoch [6/15], Iter [100,430] Loss:3.3115, average_loss: 3.3718
# Epoch [6/15], Iter [110,430] Loss:3.4763, average_loss: 3.3757
# Epoch [6/15], Iter [120,430] Loss:3.0439, average_loss: 3.3984
# Epoch [6/15], Iter [130,430] Loss:6.2140, average_loss: 3.5427
# Epoch [6/15], Iter [140,430] Loss:4.1821, average_loss: 3.5184
# Epoch [6/15], Iter [150,430] Loss:4.2591, average_loss: 3.4915
# Epoch [6/15], Iter [160,430] Loss:2.7549, average_loss: 3.4834
# Epoch [6/15], Iter [170,430] Loss:2.5880, average_loss: 3.4613
# Epoch [6/15], Iter [180,430] Loss:5.9374, average_loss: 3.4618
# Epoch [6/15], Iter [190,430] Loss:3.0436, average_loss: 3.4760
# Epoch [6/15], Iter [200,430] Loss:1.7874, average_loss: 3.4703
# Epoch [6/15], Iter [210,430] Loss:3.8410, average_loss: 3.4987
# Epoch [6/15], Iter [220,430] Loss:2.7911, average_loss: 3.5052
# Epoch [6/15], Iter [230,430] Loss:2.2565, average_loss: 3.5132
# Epoch [6/15], Iter [240,430] Loss:3.5300, average_loss: 3.5146
# Epoch [6/15], Iter [250,430] Loss:2.1265, average_loss: 3.4946
# Epoch [6/15], Iter [260,430] Loss:3.1687, average_loss: 3.4969
# Epoch [6/15], Iter [270,430] Loss:3.1820, average_loss: 3.4879
# Epoch [6/15], Iter [280,430] Loss:2.2597, average_loss: 3.4843
# Epoch [6/15], Iter [290,430] Loss:3.4082, average_loss: 3.4799
# Epoch [6/15], Iter [300,430] Loss:3.0892, average_loss: 3.4892
# Epoch [6/15], Iter [310,430] Loss:3.0021, average_loss: 3.4899
# Epoch [6/15], Iter [320,430] Loss:3.0033, average_loss: 3.4738
# Epoch [6/15], Iter [330,430] Loss:3.8106, average_loss: 3.4685
# Epoch [6/15], Iter [340,430] Loss:4.1477, average_loss: 3.4778
# Epoch [6/15], Iter [350,430] Loss:2.4669, average_loss: 3.4718
# Epoch [6/15], Iter [360,430] Loss:7.2861, average_loss: 3.4748
# Epoch [6/15], Iter [370,430] Loss:3.0465, average_loss: 3.4737
# Epoch [6/15], Iter [380,430] Loss:3.4398, average_loss: 3.4654
# Epoch [6/15], Iter [390,430] Loss:3.7872, average_loss: 3.4708
# Epoch [6/15], Iter [400,430] Loss:3.2529, average_loss: 3.4684
# Epoch [6/15], Iter [410,430] Loss:3.3566, average_loss: 3.4808
# Epoch [6/15], Iter [420,430] Loss:1.7637, average_loss: 3.4662
# Epoch [6/15], Iter [430,430] Loss:3.3406, average_loss: 3.4664
# Epoch [7/15], Iter [10,430] Loss:3.5906, average_loss: 3.0082
# Epoch [7/15], Iter [20,430] Loss:3.2672, average_loss: 3.3206
# Epoch [7/15], Iter [30,430] Loss:3.0444, average_loss: 3.4409
# Epoch [7/15], Iter [40,430] Loss:3.3451, average_loss: 3.4422
# Epoch [7/15], Iter [50,430] Loss:2.4449, average_loss: 3.3640
# Epoch [7/15], Iter [60,430] Loss:2.2576, average_loss: 3.2848
# Epoch [7/15], Iter [70,430] Loss:3.1986, average_loss: 3.2401
# Epoch [7/15], Iter [80,430] Loss:2.9407, average_loss: 3.2589
# Epoch [7/15], Iter [90,430] Loss:2.8607, average_loss: 3.2412
# Epoch [7/15], Iter [100,430] Loss:3.6698, average_loss: 3.2529
# Epoch [7/15], Iter [110,430] Loss:3.4260, average_loss: 3.2636
# Epoch [7/15], Iter [120,430] Loss:5.4648, average_loss: 3.2775
# Epoch [7/15], Iter [130,430] Loss:4.1115, average_loss: 3.3145
# Epoch [7/15], Iter [140,430] Loss:2.8364, average_loss: 3.2746
# Epoch [7/15], Iter [150,430] Loss:2.4141, average_loss: 3.2549
# Epoch [7/15], Iter [160,430] Loss:2.9232, average_loss: 3.2650
# Epoch [7/15], Iter [170,430] Loss:4.1593, average_loss: 3.2973
# Epoch [7/15], Iter [180,430] Loss:3.0893, average_loss: 3.2836
# Epoch [7/15], Iter [190,430] Loss:2.1525, average_loss: 3.2891
# Epoch [7/15], Iter [200,430] Loss:5.9932, average_loss: 3.2943
# Epoch [7/15], Iter [210,430] Loss:4.6442, average_loss: 3.3067
# Epoch [7/15], Iter [220,430] Loss:3.5399, average_loss: 3.3078
# Epoch [7/15], Iter [230,430] Loss:2.5831, average_loss: 3.3110
# Epoch [7/15], Iter [240,430] Loss:4.6996, average_loss: 3.3236
# Epoch [7/15], Iter [250,430] Loss:7.4894, average_loss: 3.3417
# Epoch [7/15], Iter [260,430] Loss:3.1973, average_loss: 3.3437
# Epoch [7/15], Iter [270,430] Loss:4.5929, average_loss: 3.3304
# Epoch [7/15], Iter [280,430] Loss:2.0572, average_loss: 3.3296
# Epoch [7/15], Iter [290,430] Loss:3.5853, average_loss: 3.3361
# Epoch [7/15], Iter [300,430] Loss:2.5319, average_loss: 3.3305
# Epoch [7/15], Iter [310,430] Loss:5.2229, average_loss: 3.3505
# Epoch [7/15], Iter [320,430] Loss:3.1326, average_loss: 3.3390
# Epoch [7/15], Iter [330,430] Loss:2.8469, average_loss: 3.3448
# Epoch [7/15], Iter [340,430] Loss:6.9709, average_loss: 3.3329
# Epoch [7/15], Iter [350,430] Loss:3.1490, average_loss: 3.3283
# Epoch [7/15], Iter [360,430] Loss:5.1189, average_loss: 3.3284
# Epoch [7/15], Iter [370,430] Loss:3.1810, average_loss: 3.3226
# Epoch [7/15], Iter [380,430] Loss:4.9096, average_loss: 3.3264
# Epoch [7/15], Iter [390,430] Loss:3.2262, average_loss: 3.3261
# Epoch [7/15], Iter [400,430] Loss:3.2213, average_loss: 3.3260
# Epoch [7/15], Iter [410,430] Loss:4.7619, average_loss: 3.3166
# Epoch [7/15], Iter [420,430] Loss:3.2649, average_loss: 3.3288
# Epoch [7/15], Iter [430,430] Loss:4.1214, average_loss: 3.3310
# Epoch [8/15], Iter [10,430] Loss:5.6428, average_loss: 3.6861
# Epoch [8/15], Iter [20,430] Loss:4.2544, average_loss: 3.4790
# Epoch [8/15], Iter [30,430] Loss:1.9982, average_loss: 3.2588
# Epoch [8/15], Iter [40,430] Loss:3.0518, average_loss: 3.1781
# Epoch [8/15], Iter [50,430] Loss:2.9719, average_loss: 3.1358
# Epoch [8/15], Iter [60,430] Loss:2.8990, average_loss: 3.0912
# Epoch [8/15], Iter [70,430] Loss:3.7389, average_loss: 3.1410
# Epoch [8/15], Iter [80,430] Loss:4.0974, average_loss: 3.1334
# Epoch [8/15], Iter [90,430] Loss:3.0140, average_loss: 3.1461
# Epoch [8/15], Iter [100,430] Loss:2.0094, average_loss: 3.1691
# Epoch [8/15], Iter [110,430] Loss:2.8024, average_loss: 3.1963
# Epoch [8/15], Iter [120,430] Loss:2.0618, average_loss: 3.2355
# Epoch [8/15], Iter [130,430] Loss:2.6726, average_loss: 3.2747
# Epoch [8/15], Iter [140,430] Loss:2.7663, average_loss: 3.2648
# Epoch [8/15], Iter [150,430] Loss:3.3591, average_loss: 3.2464
# Epoch [8/15], Iter [160,430] Loss:2.9939, average_loss: 3.2887
# Epoch [8/15], Iter [170,430] Loss:2.7242, average_loss: 3.2860
# Epoch [8/15], Iter [180,430] Loss:3.3934, average_loss: 3.2781
# Epoch [8/15], Iter [190,430] Loss:2.8537, average_loss: 3.2615
# Epoch [8/15], Iter [200,430] Loss:4.2556, average_loss: 3.2728
# Epoch [8/15], Iter [210,430] Loss:4.8981, average_loss: 3.2826
# Epoch [8/15], Iter [220,430] Loss:5.5476, average_loss: 3.2806
# Epoch [8/15], Iter [230,430] Loss:2.4478, average_loss: 3.2654
# Epoch [8/15], Iter [240,430] Loss:4.6130, average_loss: 3.2913
# Epoch [8/15], Iter [250,430] Loss:2.5402, average_loss: 3.2962
# Epoch [8/15], Iter [260,430] Loss:1.9843, average_loss: 3.2865
# Epoch [8/15], Iter [270,430] Loss:3.4775, average_loss: 3.2946
# Epoch [8/15], Iter [280,430] Loss:3.3899, average_loss: 3.3123
# Epoch [8/15], Iter [290,430] Loss:2.9385, average_loss: 3.3153
# Epoch [8/15], Iter [300,430] Loss:3.1549, average_loss: 3.3163
# Epoch [8/15], Iter [310,430] Loss:4.3218, average_loss: 3.3145
# Epoch [8/15], Iter [320,430] Loss:2.6011, average_loss: 3.3196
# Epoch [8/15], Iter [330,430] Loss:2.7955, average_loss: 3.3107
# Epoch [8/15], Iter [340,430] Loss:2.6193, average_loss: 3.3138
# Epoch [8/15], Iter [350,430] Loss:5.4891, average_loss: 3.3074
# Epoch [8/15], Iter [360,430] Loss:2.2675, average_loss: 3.3083
# Epoch [8/15], Iter [370,430] Loss:2.8486, average_loss: 3.3111
# Epoch [8/15], Iter [380,430] Loss:2.1042, average_loss: 3.3134
# Epoch [8/15], Iter [390,430] Loss:2.8023, average_loss: 3.3230
# Epoch [8/15], Iter [400,430] Loss:2.8130, average_loss: 3.3257
# Epoch [8/15], Iter [410,430] Loss:3.4110, average_loss: 3.3330
# Epoch [8/15], Iter [420,430] Loss:3.3785, average_loss: 3.3319
# Epoch [8/15], Iter [430,430] Loss:2.8060, average_loss: 3.3286
# Epoch [9/15], Iter [10,430] Loss:3.4201, average_loss: 3.4357
# Epoch [9/15], Iter [20,430] Loss:2.4570, average_loss: 3.5167
# Epoch [9/15], Iter [30,430] Loss:3.3286, average_loss: 3.3214
# Epoch [9/15], Iter [40,430] Loss:3.2096, average_loss: 3.3045
# Epoch [9/15], Iter [50,430] Loss:3.8444, average_loss: 3.4626
# Epoch [9/15], Iter [60,430] Loss:4.6465, average_loss: 3.4833
# Epoch [9/15], Iter [70,430] Loss:2.8334, average_loss: 3.4233
# Epoch [9/15], Iter [80,430] Loss:4.3218, average_loss: 3.4295
# Epoch [9/15], Iter [90,430] Loss:2.4948, average_loss: 3.3166
# Epoch [9/15], Iter [100,430] Loss:2.7505, average_loss: 3.3220
# Epoch [9/15], Iter [110,430] Loss:3.1454, average_loss: 3.3519
# Epoch [9/15], Iter [120,430] Loss:2.9286, average_loss: 3.3759
# Epoch [9/15], Iter [130,430] Loss:3.7898, average_loss: 3.4119
# Epoch [9/15], Iter [140,430] Loss:6.5805, average_loss: 3.4186
# Epoch [9/15], Iter [150,430] Loss:2.1675, average_loss: 3.4059
# Epoch [9/15], Iter [160,430] Loss:2.7022, average_loss: 3.4043
# Epoch [9/15], Iter [170,430] Loss:3.8038, average_loss: 3.4007
# Epoch [9/15], Iter [180,430] Loss:3.4192, average_loss: 3.3883
# Epoch [9/15], Iter [190,430] Loss:1.9605, average_loss: 3.3855
# Epoch [9/15], Iter [200,430] Loss:4.6034, average_loss: 3.3993
# Epoch [9/15], Iter [210,430] Loss:3.0993, average_loss: 3.3752
# Epoch [9/15], Iter [220,430] Loss:1.9331, average_loss: 3.3813
# Epoch [9/15], Iter [230,430] Loss:3.6154, average_loss: 3.3847
# Epoch [9/15], Iter [240,430] Loss:4.0489, average_loss: 3.3758
# Epoch [9/15], Iter [250,430] Loss:3.7995, average_loss: 3.3767
# Epoch [9/15], Iter [260,430] Loss:2.6363, average_loss: 3.3846
# Epoch [9/15], Iter [270,430] Loss:2.3218, average_loss: 3.3765
# Epoch [9/15], Iter [280,430] Loss:2.2629, average_loss: 3.3834
# Epoch [9/15], Iter [290,430] Loss:4.1377, average_loss: 3.3965
# Epoch [9/15], Iter [300,430] Loss:2.9189, average_loss: 3.3973
# Epoch [9/15], Iter [310,430] Loss:1.7526, average_loss: 3.3726
# Epoch [9/15], Iter [320,430] Loss:2.4681, average_loss: 3.3700
# Epoch [9/15], Iter [330,430] Loss:6.2130, average_loss: 3.3717
# Epoch [9/15], Iter [340,430] Loss:2.8360, average_loss: 3.3670
# Epoch [9/15], Iter [350,430] Loss:3.0865, average_loss: 3.3467
# Epoch [9/15], Iter [360,430] Loss:2.2443, average_loss: 3.3471
# Epoch [9/15], Iter [370,430] Loss:2.0377, average_loss: 3.3362
# Epoch [9/15], Iter [380,430] Loss:3.5105, average_loss: 3.3423
# Epoch [9/15], Iter [390,430] Loss:3.2990, average_loss: 3.3502
# Epoch [9/15], Iter [400,430] Loss:2.4777, average_loss: 3.3549
# Epoch [9/15], Iter [410,430] Loss:2.4318, average_loss: 3.3415
# Epoch [9/15], Iter [420,430] Loss:3.3722, average_loss: 3.3319
# Epoch [9/15], Iter [430,430] Loss:3.0774, average_loss: 3.3354
# Epoch [10/15], Iter [10,430] Loss:5.6932, average_loss: 3.9073
# Epoch [10/15], Iter [20,430] Loss:3.0454, average_loss: 3.3826
# Epoch [10/15], Iter [30,430] Loss:2.8894, average_loss: 3.4153
# Epoch [10/15], Iter [40,430] Loss:1.9113, average_loss: 3.3107
# Epoch [10/15], Iter [50,430] Loss:2.5832, average_loss: 3.1191
# Epoch [10/15], Iter [60,430] Loss:4.1485, average_loss: 3.1335
# Epoch [10/15], Iter [70,430] Loss:4.2859, average_loss: 3.2133
# Epoch [10/15], Iter [80,430] Loss:2.4506, average_loss: 3.2326
# Epoch [10/15], Iter [90,430] Loss:3.7881, average_loss: 3.2542
# Epoch [10/15], Iter [100,430] Loss:2.6426, average_loss: 3.2587
# Epoch [10/15], Iter [110,430] Loss:3.1035, average_loss: 3.2646
# Epoch [10/15], Iter [120,430] Loss:3.0880, average_loss: 3.2519
# Epoch [10/15], Iter [130,430] Loss:2.7112, average_loss: 3.2503
# Epoch [10/15], Iter [140,430] Loss:2.6302, average_loss: 3.3001
# Epoch [10/15], Iter [150,430] Loss:2.9766, average_loss: 3.2844
# Epoch [10/15], Iter [160,430] Loss:2.3906, average_loss: 3.3103
# Epoch [10/15], Iter [170,430] Loss:3.0055, average_loss: 3.3135
# Epoch [10/15], Iter [180,430] Loss:2.9076, average_loss: 3.3107
# Epoch [10/15], Iter [190,430] Loss:2.4233, average_loss: 3.2934
# Epoch [10/15], Iter [200,430] Loss:2.8542, average_loss: 3.2920
# Epoch [10/15], Iter [210,430] Loss:3.3395, average_loss: 3.2765
# Epoch [10/15], Iter [220,430] Loss:2.2421, average_loss: 3.2635
# Epoch [10/15], Iter [230,430] Loss:3.5743, average_loss: 3.2753
# Epoch [10/15], Iter [240,430] Loss:2.4497, average_loss: 3.2872
# Epoch [10/15], Iter [250,430] Loss:4.1351, average_loss: 3.3146
# Epoch [10/15], Iter [260,430] Loss:4.8120, average_loss: 3.3129
# Epoch [10/15], Iter [270,430] Loss:3.2096, average_loss: 3.3002
# Epoch [10/15], Iter [280,430] Loss:2.9982, average_loss: 3.3044
# Epoch [10/15], Iter [290,430] Loss:2.4450, average_loss: 3.3226
# Epoch [10/15], Iter [300,430] Loss:3.1318, average_loss: 3.3064
# Epoch [10/15], Iter [310,430] Loss:5.1713, average_loss: 3.3057
# Epoch [10/15], Iter [320,430] Loss:2.9916, average_loss: 3.3023
# Epoch [10/15], Iter [330,430] Loss:5.4153, average_loss: 3.3019
# Epoch [10/15], Iter [340,430] Loss:2.6962, average_loss: 3.2805
# Epoch [10/15], Iter [350,430] Loss:3.6773, average_loss: 3.2834
# Epoch [10/15], Iter [360,430] Loss:2.6204, average_loss: 3.2675
# Epoch [10/15], Iter [370,430] Loss:1.9902, average_loss: 3.2538
# Epoch [10/15], Iter [380,430] Loss:2.9107, average_loss: 3.2581
# Epoch [10/15], Iter [390,430] Loss:2.5857, average_loss: 3.2588
# Epoch [10/15], Iter [400,430] Loss:3.1994, average_loss: 3.2563
# Epoch [10/15], Iter [410,430] Loss:2.3437, average_loss: 3.2507
# Epoch [10/15], Iter [420,430] Loss:3.0386, average_loss: 3.2639
# Epoch [10/15], Iter [430,430] Loss:3.1715, average_loss: 3.2640
# Epoch [11/15], Iter [10,430] Loss:3.2575, average_loss: 3.8060
# Epoch [11/15], Iter [20,430] Loss:2.3024, average_loss: 3.6748
# Epoch [11/15], Iter [30,430] Loss:3.6568, average_loss: 3.5540
# Epoch [11/15], Iter [40,430] Loss:2.9602, average_loss: 3.5478
# Epoch [11/15], Iter [50,430] Loss:2.2622, average_loss: 3.5707
# Epoch [11/15], Iter [60,430] Loss:3.7113, average_loss: 3.5402
# Epoch [11/15], Iter [70,430] Loss:2.7379, average_loss: 3.4771
# Epoch [11/15], Iter [80,430] Loss:2.9868, average_loss: 3.4571
# Epoch [11/15], Iter [90,430] Loss:2.5464, average_loss: 3.4070
# Epoch [11/15], Iter [100,430] Loss:3.8663, average_loss: 3.4125
# Epoch [11/15], Iter [110,430] Loss:3.8506, average_loss: 3.4308
# Epoch [11/15], Iter [120,430] Loss:3.1986, average_loss: 3.3728
# Epoch [11/15], Iter [130,430] Loss:3.0798, average_loss: 3.3771
# Epoch [11/15], Iter [140,430] Loss:3.8774, average_loss: 3.3834
# Epoch [11/15], Iter [150,430] Loss:3.3306, average_loss: 3.3582
# Epoch [11/15], Iter [160,430] Loss:3.1863, average_loss: 3.3358
# Epoch [11/15], Iter [170,430] Loss:3.4662, average_loss: 3.2983
# Epoch [11/15], Iter [180,430] Loss:2.6644, average_loss: 3.2983
# Epoch [11/15], Iter [190,430] Loss:3.5562, average_loss: 3.2806
# Epoch [11/15], Iter [200,430] Loss:2.0393, average_loss: 3.2947
# Epoch [11/15], Iter [210,430] Loss:3.0492, average_loss: 3.3051
# Epoch [11/15], Iter [220,430] Loss:3.2115, average_loss: 3.3338
# Epoch [11/15], Iter [230,430] Loss:2.8298, average_loss: 3.3237
# Epoch [11/15], Iter [240,430] Loss:3.6240, average_loss: 3.3450
# Epoch [11/15], Iter [250,430] Loss:3.7662, average_loss: 3.3279
# Epoch [11/15], Iter [260,430] Loss:3.3804, average_loss: 3.3473
# Epoch [11/15], Iter [270,430] Loss:3.4868, average_loss: 3.3548
# Epoch [11/15], Iter [280,430] Loss:2.0372, average_loss: 3.3440
# Epoch [11/15], Iter [290,430] Loss:3.2041, average_loss: 3.3426
# Epoch [11/15], Iter [300,430] Loss:5.5561, average_loss: 3.3403
# Epoch [11/15], Iter [310,430] Loss:1.8319, average_loss: 3.3180
# Epoch [11/15], Iter [320,430] Loss:5.1848, average_loss: 3.3074
# Epoch [11/15], Iter [330,430] Loss:3.5152, average_loss: 3.3121
# Epoch [11/15], Iter [340,430] Loss:3.5939, average_loss: 3.2966
# Epoch [11/15], Iter [350,430] Loss:3.7642, average_loss: 3.2936
# Epoch [11/15], Iter [360,430] Loss:3.1367, average_loss: 3.2961
# Epoch [11/15], Iter [370,430] Loss:2.9958, average_loss: 3.2975
# Epoch [11/15], Iter [380,430] Loss:2.6205, average_loss: 3.3001
# Epoch [11/15], Iter [390,430] Loss:2.1401, average_loss: 3.2958
# Epoch [11/15], Iter [400,430] Loss:2.5198, average_loss: 3.3015
# Epoch [11/15], Iter [410,430] Loss:2.6301, average_loss: 3.2839
# Epoch [11/15], Iter [420,430] Loss:1.5477, average_loss: 3.2881
# Epoch [11/15], Iter [430,430] Loss:2.3960, average_loss: 3.2848
# Epoch [12/15], Iter [10,430] Loss:2.4627, average_loss: 3.7363
# Epoch [12/15], Iter [20,430] Loss:3.4189, average_loss: 3.5672
# Epoch [12/15], Iter [30,430] Loss:4.6910, average_loss: 3.8012
# Epoch [12/15], Iter [40,430] Loss:2.6270, average_loss: 3.5889
# Epoch [12/15], Iter [50,430] Loss:3.0127, average_loss: 3.5733
# Epoch [12/15], Iter [60,430] Loss:3.1661, average_loss: 3.5113
# Epoch [12/15], Iter [70,430] Loss:4.4333, average_loss: 3.5641
# Epoch [12/15], Iter [80,430] Loss:2.0464, average_loss: 3.5456
# Epoch [12/15], Iter [90,430] Loss:2.6767, average_loss: 3.4930
# Epoch [12/15], Iter [100,430] Loss:3.4527, average_loss: 3.5098
# Epoch [12/15], Iter [110,430] Loss:3.0500, average_loss: 3.4901
# Epoch [12/15], Iter [120,430] Loss:5.6863, average_loss: 3.4694
# Epoch [12/15], Iter [130,430] Loss:3.2253, average_loss: 3.4659
# Epoch [12/15], Iter [140,430] Loss:2.9941, average_loss: 3.4477
# Epoch [12/15], Iter [150,430] Loss:3.0435, average_loss: 3.4155
# Epoch [12/15], Iter [160,430] Loss:2.6099, average_loss: 3.3890
# Epoch [12/15], Iter [170,430] Loss:3.8563, average_loss: 3.4076
# Epoch [12/15], Iter [180,430] Loss:2.9396, average_loss: 3.3822
# Epoch [12/15], Iter [190,430] Loss:4.2737, average_loss: 3.3744
# Epoch [12/15], Iter [200,430] Loss:4.5733, average_loss: 3.3785
# Epoch [12/15], Iter [210,430] Loss:2.1233, average_loss: 3.3716
# Epoch [12/15], Iter [220,430] Loss:2.6366, average_loss: 3.3524
# Epoch [12/15], Iter [230,430] Loss:2.3175, average_loss: 3.3460
# Epoch [12/15], Iter [240,430] Loss:3.0908, average_loss: 3.3313
# Epoch [12/15], Iter [250,430] Loss:3.4645, average_loss: 3.3534
# Epoch [12/15], Iter [260,430] Loss:2.8367, average_loss: 3.3406
# Epoch [12/15], Iter [270,430] Loss:5.0261, average_loss: 3.3607
# Epoch [12/15], Iter [280,430] Loss:5.4670, average_loss: 3.3528
# Epoch [12/15], Iter [290,430] Loss:2.4575, average_loss: 3.3480
# Epoch [12/15], Iter [300,430] Loss:2.9456, average_loss: 3.3278
# Epoch [12/15], Iter [310,430] Loss:5.0627, average_loss: 3.3290
# Epoch [12/15], Iter [320,430] Loss:2.9305, average_loss: 3.3110
# Epoch [12/15], Iter [330,430] Loss:5.3093, average_loss: 3.3063
# Epoch [12/15], Iter [340,430] Loss:2.0590, average_loss: 3.3100
# Epoch [12/15], Iter [350,430] Loss:2.7008, average_loss: 3.3150
# Epoch [12/15], Iter [360,430] Loss:2.0722, average_loss: 3.3153
# Epoch [12/15], Iter [370,430] Loss:2.9648, average_loss: 3.3018
# Epoch [12/15], Iter [380,430] Loss:3.9512, average_loss: 3.3146
# Epoch [12/15], Iter [390,430] Loss:1.9415, average_loss: 3.3103
# Epoch [12/15], Iter [400,430] Loss:3.0433, average_loss: 3.3009
# Epoch [12/15], Iter [410,430] Loss:3.2868, average_loss: 3.3061
# Epoch [12/15], Iter [420,430] Loss:3.4422, average_loss: 3.3123
# Epoch [12/15], Iter [430,430] Loss:2.5167, average_loss: 3.3120
# Epoch [13/15], Iter [10,430] Loss:2.1647, average_loss: 3.2668
# Epoch [13/15], Iter [20,430] Loss:3.8285, average_loss: 3.3796
# Epoch [13/15], Iter [30,430] Loss:3.3569, average_loss: 3.3068
# Epoch [13/15], Iter [40,430] Loss:2.7337, average_loss: 3.3446
# Epoch [13/15], Iter [50,430] Loss:3.4305, average_loss: 3.2579
# Epoch [13/15], Iter [60,430] Loss:4.1021, average_loss: 3.3176
# Epoch [13/15], Iter [70,430] Loss:4.0187, average_loss: 3.3713
# Epoch [13/15], Iter [80,430] Loss:1.5956, average_loss: 3.3352
# Epoch [13/15], Iter [90,430] Loss:3.0691, average_loss: 3.3042
# Epoch [13/15], Iter [100,430] Loss:3.6125, average_loss: 3.3088
# Epoch [13/15], Iter [110,430] Loss:3.4939, average_loss: 3.3435
# Epoch [13/15], Iter [120,430] Loss:3.9201, average_loss: 3.3563
# Epoch [13/15], Iter [130,430] Loss:4.6358, average_loss: 3.3321
# Epoch [13/15], Iter [140,430] Loss:5.6208, average_loss: 3.3607
# Epoch [13/15], Iter [150,430] Loss:2.7536, average_loss: 3.3666
# Epoch [13/15], Iter [160,430] Loss:2.1602, average_loss: 3.3339
# Epoch [13/15], Iter [170,430] Loss:3.7532, average_loss: 3.3375
# Epoch [13/15], Iter [180,430] Loss:2.7801, average_loss: 3.3268
# Epoch [13/15], Iter [190,430] Loss:3.5245, average_loss: 3.3269
# Epoch [13/15], Iter [200,430] Loss:4.6114, average_loss: 3.3457
# Epoch [13/15], Iter [210,430] Loss:3.7621, average_loss: 3.3322
# Epoch [13/15], Iter [220,430] Loss:2.4964, average_loss: 3.3160
# Epoch [13/15], Iter [230,430] Loss:3.3207, average_loss: 3.3097
# Epoch [13/15], Iter [240,430] Loss:2.2212, average_loss: 3.2979
# Epoch [13/15], Iter [250,430] Loss:4.4984, average_loss: 3.2848
# Epoch [13/15], Iter [260,430] Loss:3.3841, average_loss: 3.2988
# Epoch [13/15], Iter [270,430] Loss:2.8436, average_loss: 3.3035
# Epoch [13/15], Iter [280,430] Loss:2.0629, average_loss: 3.3119
# Epoch [13/15], Iter [290,430] Loss:3.1316, average_loss: 3.2850
# Epoch [13/15], Iter [300,430] Loss:2.4000, average_loss: 3.2755
# Epoch [13/15], Iter [310,430] Loss:3.9757, average_loss: 3.2762
# Epoch [13/15], Iter [320,430] Loss:3.1898, average_loss: 3.2765
# Epoch [13/15], Iter [330,430] Loss:3.5998, average_loss: 3.2696
# Epoch [13/15], Iter [340,430] Loss:2.5103, average_loss: 3.2650
# Epoch [13/15], Iter [350,430] Loss:3.9977, average_loss: 3.2786
# Epoch [13/15], Iter [360,430] Loss:3.5709, average_loss: 3.2787
# Epoch [13/15], Iter [370,430] Loss:4.2492, average_loss: 3.2831
# Epoch [13/15], Iter [380,430] Loss:2.0067, average_loss: 3.2827
# Epoch [13/15], Iter [390,430] Loss:3.6036, average_loss: 3.2870
# Epoch [13/15], Iter [400,430] Loss:2.0785, average_loss: 3.2764
# Epoch [13/15], Iter [410,430] Loss:2.0839, average_loss: 3.2766
# Epoch [13/15], Iter [420,430] Loss:4.4118, average_loss: 3.2876
# Epoch [13/15], Iter [430,430] Loss:4.0337, average_loss: 3.2974
# Epoch [14/15], Iter [10,430] Loss:2.6248, average_loss: 3.9838
# Epoch [14/15], Iter [20,430] Loss:2.3609, average_loss: 3.5479
# Epoch [14/15], Iter [30,430] Loss:4.7305, average_loss: 3.5260
# Epoch [14/15], Iter [40,430] Loss:3.2059, average_loss: 3.4074
# Epoch [14/15], Iter [50,430] Loss:2.8843, average_loss: 3.4393
# Epoch [14/15], Iter [60,430] Loss:4.4175, average_loss: 3.4201
# Epoch [14/15], Iter [70,430] Loss:2.3314, average_loss: 3.3731
# Epoch [14/15], Iter [80,430] Loss:2.5805, average_loss: 3.3202
# Epoch [14/15], Iter [90,430] Loss:2.0222, average_loss: 3.3198
# Epoch [14/15], Iter [100,430] Loss:3.3449, average_loss: 3.3961
# Epoch [14/15], Iter [110,430] Loss:2.2032, average_loss: 3.3681
# Epoch [14/15], Iter [120,430] Loss:3.5446, average_loss: 3.3629
# Epoch [14/15], Iter [130,430] Loss:2.8598, average_loss: 3.3313
# Epoch [14/15], Iter [140,430] Loss:3.0478, average_loss: 3.3263
# Epoch [14/15], Iter [150,430] Loss:2.2167, average_loss: 3.3719
# Epoch [14/15], Iter [160,430] Loss:2.5991, average_loss: 3.3530
# Epoch [14/15], Iter [170,430] Loss:3.5578, average_loss: 3.3692
# Epoch [14/15], Iter [180,430] Loss:2.6397, average_loss: 3.3604
# Epoch [14/15], Iter [190,430] Loss:2.4509, average_loss: 3.3313
# Epoch [14/15], Iter [200,430] Loss:3.9460, average_loss: 3.3218
# Epoch [14/15], Iter [210,430] Loss:2.7873, average_loss: 3.3170
# Epoch [14/15], Iter [220,430] Loss:4.9629, average_loss: 3.3571
# Epoch [14/15], Iter [230,430] Loss:4.8705, average_loss: 3.3804
# Epoch [14/15], Iter [240,430] Loss:5.8476, average_loss: 3.3928
# Epoch [14/15], Iter [250,430] Loss:3.5972, average_loss: 3.3921
# Epoch [14/15], Iter [260,430] Loss:2.0979, average_loss: 3.3764
# Epoch [14/15], Iter [270,430] Loss:3.6884, average_loss: 3.3700
# Epoch [14/15], Iter [280,430] Loss:3.0159, average_loss: 3.3686
# Epoch [14/15], Iter [290,430] Loss:3.6144, average_loss: 3.3563
# Epoch [14/15], Iter [300,430] Loss:2.5836, average_loss: 3.3404
# Epoch [14/15], Iter [310,430] Loss:2.8349, average_loss: 3.3418
# Epoch [14/15], Iter [320,430] Loss:4.0796, average_loss: 3.3392
# Epoch [14/15], Iter [330,430] Loss:2.7637, average_loss: 3.3251
# Epoch [14/15], Iter [340,430] Loss:4.3750, average_loss: 3.3331
# Epoch [14/15], Iter [350,430] Loss:2.4064, average_loss: 3.3310
# Epoch [14/15], Iter [360,430] Loss:2.5810, average_loss: 3.3204
# Epoch [14/15], Iter [370,430] Loss:2.6458, average_loss: 3.3155
# Epoch [14/15], Iter [380,430] Loss:3.8038, average_loss: 3.3084
# Epoch [14/15], Iter [390,430] Loss:2.4322, average_loss: 3.3054
# Epoch [14/15], Iter [400,430] Loss:2.5928, average_loss: 3.2948
# Epoch [14/15], Iter [410,430] Loss:3.5380, average_loss: 3.2948
# Epoch [14/15], Iter [420,430] Loss:2.2408, average_loss: 3.2850
# Epoch [14/15], Iter [430,430] Loss:3.5236, average_loss: 3.2849
# Epoch [15/15], Iter [10,430] Loss:4.2338, average_loss: 3.6291
# Epoch [15/15], Iter [20,430] Loss:3.5249, average_loss: 3.4875
# Epoch [15/15], Iter [30,430] Loss:3.5293, average_loss: 3.4640
# Epoch [15/15], Iter [40,430] Loss:3.3541, average_loss: 3.4589
# Epoch [15/15], Iter [50,430] Loss:2.6311, average_loss: 3.4397
# Epoch [15/15], Iter [60,430] Loss:3.8261, average_loss: 3.3710
# Epoch [15/15], Iter [70,430] Loss:4.4822, average_loss: 3.3193
# Epoch [15/15], Iter [80,430] Loss:3.3753, average_loss: 3.3288
# Epoch [15/15], Iter [90,430] Loss:2.8218, average_loss: 3.2683
# Epoch [15/15], Iter [100,430] Loss:3.1617, average_loss: 3.3131
# Epoch [15/15], Iter [110,430] Loss:2.3393, average_loss: 3.2998
# Epoch [15/15], Iter [120,430] Loss:2.7892, average_loss: 3.2817
# Epoch [15/15], Iter [130,430] Loss:2.5320, average_loss: 3.2618
# Epoch [15/15], Iter [140,430] Loss:2.0128, average_loss: 3.2961
# Epoch [15/15], Iter [150,430] Loss:2.9821, average_loss: 3.2899
# Epoch [15/15], Iter [160,430] Loss:2.9599, average_loss: 3.2780
# Epoch [15/15], Iter [170,430] Loss:2.3103, average_loss: 3.3262
# Epoch [15/15], Iter [180,430] Loss:2.8131, average_loss: 3.3464
# Epoch [15/15], Iter [190,430] Loss:2.6670, average_loss: 3.3418
# Epoch [15/15], Iter [200,430] Loss:2.5753, average_loss: 3.3462
# Epoch [15/15], Iter [210,430] Loss:1.4443, average_loss: 3.3249
# Epoch [15/15], Iter [220,430] Loss:2.6081, average_loss: 3.3155
# Epoch [15/15], Iter [230,430] Loss:4.9351, average_loss: 3.3123
# Epoch [15/15], Iter [240,430] Loss:2.5578, average_loss: 3.3264
# Epoch [15/15], Iter [250,430] Loss:4.8426, average_loss: 3.3308
# Epoch [15/15], Iter [260,430] Loss:2.7781, average_loss: 3.3189
# Epoch [15/15], Iter [270,430] Loss:4.1379, average_loss: 3.3082
# Epoch [15/15], Iter [280,430] Loss:3.0938, average_loss: 3.3040
# Epoch [15/15], Iter [290,430] Loss:2.7506, average_loss: 3.3234
# Epoch [15/15], Iter [300,430] Loss:2.4219, average_loss: 3.3310
# Epoch [15/15], Iter [310,430] Loss:3.5387, average_loss: 3.3472
# Epoch [15/15], Iter [320,430] Loss:1.5798, average_loss: 3.3301
# Epoch [15/15], Iter [330,430] Loss:3.6876, average_loss: 3.3283
# Epoch [15/15], Iter [340,430] Loss:3.0159, average_loss: 3.3435
# Epoch [15/15], Iter [350,430] Loss:2.7284, average_loss: 3.3207
# Epoch [15/15], Iter [360,430] Loss:4.2757, average_loss: 3.3122
# Epoch [15/15], Iter [370,430] Loss:3.9105, average_loss: 3.3088
# Epoch [15/15], Iter [380,430] Loss:4.1389, average_loss: 3.3217
# Epoch [15/15], Iter [390,430] Loss:3.2790, average_loss: 3.3272
# Epoch [15/15], Iter [400,430] Loss:2.0886, average_loss: 3.3341
# Epoch [15/15], Iter [410,430] Loss:2.1490, average_loss: 3.3247
# Epoch [15/15], Iter [420,430] Loss:2.6019, average_loss: 3.3256
# Epoch [15/15], Iter [430,430] Loss:3.5474, average_loss: 3.3139

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from lab2.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])

    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]

    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)

    plt.imshow(img)

model.eval()
visualize(model, './lab2/utils/Generate_dataset/images/003033.jpg')

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./lab2/utils/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)

    txt_file = open('./lab2/utils/Generate_dataset/predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()

import glob

model.eval()
img_names = glob.glob('./lab2/utils/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500

# %%
# %run ./lab2/utils/Generate_dataset/main.py
# Out:
# 50.63% = aeroplane AP
# 59.67% = bicycle AP
# 43.69% = bus AP
# 47.33% = car AP
# 63.04% = cat AP
# 66.34% = dog AP
# mAP = 55.11%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
